# %% [markdown]
# # Playing Simple Catch Videogame with Keras and Evolution Strategy
#
# Eder Santana blog post: https://medium.com/@edersantana/mve-series-playing-catch-with-keras-and-an-evolution-strategy-a005b75d0505
#
# Eder Santana GitHub repo: https://github.com/EderSantana/EvolutionMVE
#
# Small corection and addition of this iPython Notebook by Claude COULOMBE - PhD candidate - TÉLUQ / UQAM - Montréal
#
# ### Introduction
#
# Whenever I want to learn a new machine learning method, I write a single file example with a Minimum Viable Experiment (MVE). Last time I did an MVE to learn <a href="http://edersantana.github.io/articles/keras_rl/">RL and Q-Learning</a>. This time I want to learn <a href="https://arxiv.org/abs/1703.03864">Evolution Strategies</a>.
#
# <img src="CatchVideogame_ES_Original.gif" width=200>
# Before I show you the code I came up with, let us talk a bit about a fun recurring equation. Say you want to create a model of a variable  $\textbf{y}$ (ex. price of a stock, say if an image shows a cat or a dog, the steering of a self driving car, etc). You go ahead and use a model  $\textbf{f(x)}$  to approximate $\textbf{y}$. Where $\textbf{x}$ are inputs (ex. previous stock values, a jpeg image, a video of the road, etc). That model $\textbf{f}$ also have parameters $\textbf{w}$ to be tuned. Just like in a neural network that at this point everybody heard about.
#
# A simple way to measure how well your model performs is to calculate the average value of
# $L = (y-f(x))^2$. Then, you can update the parameters $\textbf{w}$ using information about the gradient of L:
#
# $\nabla L = -2(y-f(x))*\nabla f(x)$.
#
# Note that there are two main terms multiplied in the last equation. A quality measure $-2(y-f(x))$ and a model sensitivity $\nabla f(x)$. If we forget precise formulations for a bit and just think about matching possible quality measures and model sensitivity, we can see that this same equation is used elsewhere, especially in reinforcement learning (RL). For example, the REINFORCE algorithm also updates model parameters according to $R*\nabla(log(p(x))$ where $\textbf{R}$ is a reward measure and $log(p(x))$ is a log-probability of certain actions of a policy function.
#
# Taking this to an extreme, where we assume that a model sensitivity is solely defined by small random jitters $\textbf{n}$  we add to our model parameters $\textbf{w}$, we get $\nabla L = R * n$. Where again $\textbf{R}$ are rewards defined by completing a given task. Obviously that approximation is not really precise and should have a lot of errors when estimating good values to update $\textbf{w}$. Good thing about it is we can usually compensate for lack of precision with exhaustive trial, error and lots of data.
#
# And that's it! We can now try to solve the same catch videogame from the previous post, but this time with a much simpler formulation. The trade off is more compute. Now you can <a href="https://github.com/EderSantana/EvolutionMVE">check out the code</a>. It is pretty short and should be simple to understand, but let me know if something isn’t clear.
#
# P.-S.: After you are done understanding the basics of evolution strategies, I’d recommend using more serious code bases like <a href="https://github.com/openai/evolution-strategies-starter">OpenAI ES</a>, <a href="https://github.com/hardmaru/estool">estools</a> or <a href="https://github.com/alirezamika/evostra">evostra</a> for further experiments. Also check out <a href="http://blog.otoro.net/2017/10/29/visual-evolution-strategies/">A Visual Guide to Evolution Strategies</a> for more evolution strategies and nice visualizations.

# %%
import json
import numpy as np
import tensorflow as tf
import keras

Sequential =  keras.models.Sequential
Dense = keras.layers.Dense
sgd = keras.optimizers.SGD

class Catch(object):
    def __init__(self, grid_size=10):
        self.grid_size = grid_size
        self.reset()

    def _update_state(self, action):
        """
        Input: action and states
        Ouput: new states and reward
        """
        state = self.state
        if action == 0:  # left
            action = -1
        elif action == 1:  # stay
            action = 0
        else:
            action = 1  # right
        f0, f1, basket = state[0]
        new_basket = min(max(1, basket + action), self.grid_size-1)
        f0 += 1
        out = np.asarray([f0, f1, new_basket])
        out = out[np.newaxis]

        assert len(out.shape) == 2
        self.state = out

    def _draw_state(self):
        im_size = (self.grid_size,)*2
        state = self.state[0]
        canvas = np.zeros(im_size)
        canvas[state[0], state[1]] = 1  # draw fruit
        canvas[-1, state[2]-1:state[2] + 2] = 1  # draw basket
        return canvas

    def _get_reward(self):
        fruit_row, fruit_col, basket = self.state[0]
        if fruit_row == self.grid_size-1:
            if abs(fruit_col - basket) <= 1:
                return 1
            else:
                return 0 
        else:
            return 0

    def _is_over(self):
        if self.state[0, 0] == self.grid_size-1:
            return True
        else:
            return False

    def observe(self):
        canvas = self._draw_state()
        return canvas.reshape((1, -1))

    def act(self, action):
        self._update_state(action)
        reward = self._get_reward()
        game_over = self._is_over()
        return self.observe(), reward, game_over

    def reset(self):
        n = np.random.randint(0, self.grid_size-1, size=1)
        m = np.random.randint(1, self.grid_size-2, size=1)
        self.state = np.asarray([0, n, m])[np.newaxis]


def play_round(model, grid_size):
    # Define environment/game
    env = Catch(grid_size)
    input_t = env.observe()
    game_over = False

    while not game_over:
        input_tm1 = input_t
        # get next action
        q = model.predict(input_tm1)
        action = np.argmax(q[0])

        # apply action, get rewards and new state
        input_t, reward, game_over = env.act(action)

    return reward

if __name__ == "__main__":
    # parameters
    num_actions = 3  # [move_left, stay, move_right]
    epoch = 5000  # how many runs 
    hidden_size = 100
    population_size = 100  # how many different random agents per run
    learning_rate = .1
    sigma = .5  # std of the noise that defines weight perturbation (with large sigma you explore further, but may never really get anywhere)
    grid_size = 10
    games_per_agent = 5

    # this model is smaller than the Q-learning model (see the comment oriented programming, COP, down there?)
    model = Sequential()
    model.add(Dense(hidden_size, input_shape=(grid_size**2,), activation='relu'))
    #model.add(Dense(hidden_size, activation='relu'))
    model.add(Dense(num_actions))
    model.compile(sgd(lr=.2), "mse")

    # If you want to continue training from a previous model, just uncomment the line bellow (I love COP)
    # model.load_weights("model.h5")

    # Train
    for e in range(epoch):
        weights = model.get_weights()
        all_eps = []
        rewards = np.zeros(population_size)
        for i, p in enumerate(range(population_size)):
            new_weights = []
            eps = []
            for w in weights:
                eps.append(np.random.randn(*w.shape))
                new_weights.append(w + sigma * eps[-1])
            all_eps.append(eps)
            model.set_weights(new_weights) 
            for j in range(games_per_agent):
                rewards[i] += play_round(model, grid_size)

        # total reward of everything explored
        win_cnt = rewards.sum()
        reward_norm = (rewards - rewards.mean()) / rewards.std()

        # correlate reward with noise and update weights
        updated_weights = []
        for index, w in enumerate(weights):
            X = np.array([eps[index] for eps in all_eps])  # all noise added to weight[index]
            w = w + learning_rate / (population_size * sigma) * X.T.dot(reward_norm).T
            updated_weights.append(w)

        # your new model is good to go
        model.set_weights(updated_weights)

        # decay learning rate
        # learning_rate *= .993

        print("Epoch {:03d}/{:04d} | Win count {}".format(e, epoch-1, win_cnt))
             
    # Save trained model weights and architecture, this will be used by the visualization code
    model.save_weights("model.h5", overwrite=True)
    with open("model.json", "w") as outfile:
        json.dump(model.to_json(), outfile)
        
    print("Training completed!")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Epoch 000/4999 | Win count 145.0
# Epoch 001/4999 | Win count 142.0
# Epoch 002/4999 | Win count 146.0
# Epoch 003/4999 | Win count 153.0
# Epoch 004/4999 | Win count 140.0
# Epoch 005/4999 | Win count 118.0
# Epoch 006/4999 | Win count 166.0
# Epoch 007/4999 | Win count 153.0
# Epoch 008/4999 | Win count 172.0
# Epoch 009/4999 | Win count 156.0
# Epoch 010/4999 | Win count 159.0
# Epoch 011/4999 | Win count 146.0
# Epoch 012/4999 | Win count 155.0
# Epoch 013/4999 | Win count 179.0
# Epoch 014/4999 | Win count 143.0
# Epoch 015/4999 | Win count 175.0
# Epoch 016/4999 | Win count 141.0
# Epoch 017/4999 | Win count 167.0
# Epoch 018/4999 | Win count 161.0
# Epoch 019/4999 | Win count 156.0
# Epoch 020/4999 | Win count 157.0
# Epoch 021/4999 | Win count 171.0
# Epoch 022/4999 | Win count 165.0
# Epoch 023/4999 | Win count 143.0
# Epoch 024/4999 | Win count 161.0
# Epoch 025/4999 | Win count 156.0
# Epoch 026/4999 | Win count 181.0
# Epoch 027/4999 | Win count 157.0
# Epoch 028/4999 | Win count 185.0
# Epoch 029/4999 | Win count 159.0
# Epoch 030/4999 | Win count 171.0
# Epoch 031/4999 | Win count 173.0
# Epoch 032/4999 | Win count 148.0
# Epoch 033/4999 | Win count 161.0
# Epoch 034/4999 | Win count 165.0
# Epoch 035/4999 | Win count 160.0
# Epoch 036/4999 | Win count 146.0
# Epoch 037/4999 | Win count 161.0
# Epoch 038/4999 | Win count 162.0
# Epoch 039/4999 | Win count 143.0
# Epoch 040/4999 | Win count 151.0
# Epoch 041/4999 | Win count 167.0
# Epoch 042/4999 | Win count 173.0
# Epoch 043/4999 | Win count 162.0
# Epoch 044/4999 | Win count 181.0
# Epoch 045/4999 | Win count 144.0
# Epoch 046/4999 | Win count 164.0
# Epoch 047/4999 | Win count 156.0
# Epoch 048/4999 | Win count 161.0
# Epoch 049/4999 | Win count 172.0
# Epoch 050/4999 | Win count 151.0
# Epoch 051/4999 | Win count 163.0
# Epoch 052/4999 | Win count 159.0
# Epoch 053/4999 | Win count 161.0
# Epoch 054/4999 | Win count 167.0
# Epoch 055/4999 | Win count 152.0
# Epoch 056/4999 | Win count 157.0
# Epoch 057/4999 | Win count 168.0
# Epoch 058/4999 | Win count 157.0
# Epoch 059/4999 | Win count 167.0
# Epoch 060/4999 | Win count 167.0
# Epoch 061/4999 | Win count 168.0
# Epoch 062/4999 | Win count 160.0
# Epoch 063/4999 | Win count 175.0
# Epoch 064/4999 | Win count 176.0
# Epoch 065/4999 | Win count 173.0
# Epoch 066/4999 | Win count 154.0
# Epoch 067/4999 | Win count 167.0
# Epoch 068/4999 | Win count 170.0
# Epoch 069/4999 | Win count 181.0
# Epoch 070/4999 | Win count 171.0
# Epoch 071/4999 | Win count 165.0
# Epoch 072/4999 | Win count 170.0
# Epoch 073/4999 | Win count 168.0
# Epoch 074/4999 | Win count 154.0
# Epoch 075/4999 | Win count 153.0
# Epoch 076/4999 | Win count 161.0
# Epoch 077/4999 | Win count 181.0
# Epoch 078/4999 | Win count 181.0
# Epoch 079/4999 | Win count 142.0
# Epoch 080/4999 | Win count 169.0
# Epoch 081/4999 | Win count 182.0
# Epoch 082/4999 | Win count 156.0
# Epoch 083/4999 | Win count 184.0
# Epoch 084/4999 | Win count 179.0
# Epoch 085/4999 | Win count 170.0
# Epoch 086/4999 | Win count 161.0
# Epoch 087/4999 | Win count 155.0
# Epoch 088/4999 | Win count 142.0
# Epoch 089/4999 | Win count 162.0
# Epoch 090/4999 | Win count 169.0
# Epoch 091/4999 | Win count 143.0
# Epoch 092/4999 | Win count 179.0
# Epoch 093/4999 | Win count 159.0
# Epoch 094/4999 | Win count 153.0
# Epoch 095/4999 | Win count 182.0
# Epoch 096/4999 | Win count 149.0
# Epoch 097/4999 | Win count 161.0
# Epoch 098/4999 | Win count 168.0
# Epoch 099/4999 | Win count 155.0
# Epoch 100/4999 | Win count 176.0
# Epoch 101/4999 | Win count 170.0
# Epoch 102/4999 | Win count 167.0
# Epoch 103/4999 | Win count 159.0
# Epoch 104/4999 | Win count 162.0
# Epoch 105/4999 | Win count 182.0
# Epoch 106/4999 | Win count 176.0
# Epoch 107/4999 | Win count 161.0
# Epoch 108/4999 | Win count 161.0
# Epoch 109/4999 | Win count 181.0
# Epoch 110/4999 | Win count 173.0
# Epoch 111/4999 | Win count 162.0
# Epoch 112/4999 | Win count 176.0
# Epoch 113/4999 | Win count 165.0
# Epoch 114/4999 | Win count 163.0
# Epoch 115/4999 | Win count 161.0
# Epoch 116/4999 | Win count 183.0
# Epoch 117/4999 | Win count 150.0
# Epoch 118/4999 | Win count 172.0
# Epoch 119/4999 | Win count 179.0
# Epoch 120/4999 | Win count 152.0
# Epoch 121/4999 | Win count 164.0
# Epoch 122/4999 | Win count 160.0
# Epoch 123/4999 | Win count 147.0
# Epoch 124/4999 | Win count 149.0
# Epoch 125/4999 | Win count 181.0
# Epoch 126/4999 | Win count 174.0
# Epoch 127/4999 | Win count 165.0
# Epoch 128/4999 | Win count 170.0
# Epoch 129/4999 | Win count 177.0
# Epoch 130/4999 | Win count 183.0
# Epoch 131/4999 | Win count 162.0
# Epoch 132/4999 | Win count 165.0
# Epoch 133/4999 | Win count 142.0
# Epoch 134/4999 | Win count 167.0
# Epoch 135/4999 | Win count 175.0
# Epoch 136/4999 | Win count 171.0
# Epoch 137/4999 | Win count 164.0
# Epoch 138/4999 | Win count 156.0
# Epoch 139/4999 | Win count 177.0
# Epoch 140/4999 | Win count 173.0
# Epoch 141/4999 | Win count 168.0
# Epoch 142/4999 | Win count 179.0
# Epoch 143/4999 | Win count 190.0
# Epoch 144/4999 | Win count 177.0
# Epoch 145/4999 | Win count 168.0
# Epoch 146/4999 | Win count 156.0
# Epoch 147/4999 | Win count 166.0
# Epoch 148/4999 | Win count 160.0
# Epoch 149/4999 | Win count 177.0
# Epoch 150/4999 | Win count 173.0
# Epoch 151/4999 | Win count 169.0
# Epoch 152/4999 | Win count 164.0
# Epoch 153/4999 | Win count 186.0
# Epoch 154/4999 | Win count 166.0
# Epoch 155/4999 | Win count 167.0
# Epoch 156/4999 | Win count 167.0
# Epoch 157/4999 | Win count 156.0
# Epoch 158/4999 | Win count 165.0
# Epoch 159/4999 | Win count 181.0
# Epoch 160/4999 | Win count 152.0
# Epoch 161/4999 | Win count 158.0
# Epoch 162/4999 | Win count 166.0
# Epoch 163/4999 | Win count 170.0
# Epoch 164/4999 | Win count 163.0
# Epoch 165/4999 | Win count 176.0
# Epoch 166/4999 | Win count 163.0
# Epoch 167/4999 | Win count 177.0
# Epoch 168/4999 | Win count 174.0
# Epoch 169/4999 | Win count 165.0
# Epoch 170/4999 | Win count 171.0
# Epoch 171/4999 | Win count 158.0
# Epoch 172/4999 | Win count 175.0
# Epoch 173/4999 | Win count 179.0
# Epoch 174/4999 | Win count 177.0
# Epoch 175/4999 | Win count 175.0
# Epoch 176/4999 | Win count 171.0
# Epoch 177/4999 | Win count 176.0
# Epoch 178/4999 | Win count 183.0
# Epoch 179/4999 | Win count 162.0
# Epoch 180/4999 | Win count 158.0
# Epoch 181/4999 | Win count 163.0
# Epoch 182/4999 | Win count 183.0
# Epoch 183/4999 | Win count 173.0
# Epoch 184/4999 | Win count 173.0
# Epoch 185/4999 | Win count 173.0
# Epoch 186/4999 | Win count 177.0
# Epoch 187/4999 | Win count 200.0
# Epoch 188/4999 | Win count 174.0
# Epoch 189/4999 | Win count 166.0
# Epoch 190/4999 | Win count 186.0
# Epoch 191/4999 | Win count 180.0
# Epoch 192/4999 | Win count 159.0
# Epoch 193/4999 | Win count 174.0
# Epoch 194/4999 | Win count 183.0
# Epoch 195/4999 | Win count 179.0
# Epoch 196/4999 | Win count 171.0
# Epoch 197/4999 | Win count 161.0
# Epoch 198/4999 | Win count 156.0
# Epoch 199/4999 | Win count 154.0
# Epoch 200/4999 | Win count 163.0
# Epoch 201/4999 | Win count 173.0
# Epoch 202/4999 | Win count 168.0
# Epoch 203/4999 | Win count 185.0
# Epoch 204/4999 | Win count 156.0
# Epoch 205/4999 | Win count 179.0
# Epoch 206/4999 | Win count 151.0
# Epoch 207/4999 | Win count 156.0
# Epoch 208/4999 | Win count 175.0
# Epoch 209/4999 | Win count 146.0
# Epoch 210/4999 | Win count 153.0
# Epoch 211/4999 | Win count 159.0
# Epoch 212/4999 | Win count 150.0
# Epoch 213/4999 | Win count 158.0
# Epoch 214/4999 | Win count 158.0
# Epoch 215/4999 | Win count 167.0
# Epoch 216/4999 | Win count 165.0
# Epoch 217/4999 | Win count 177.0
# Epoch 218/4999 | Win count 161.0
# Epoch 219/4999 | Win count 157.0
# Epoch 220/4999 | Win count 155.0
# Epoch 221/4999 | Win count 172.0
# Epoch 222/4999 | Win count 176.0
# Epoch 223/4999 | Win count 164.0
# Epoch 224/4999 | Win count 170.0
# Epoch 225/4999 | Win count 167.0
# Epoch 226/4999 | Win count 174.0
# Epoch 227/4999 | Win count 158.0
# Epoch 228/4999 | Win count 171.0
# Epoch 229/4999 | Win count 188.0
# Epoch 230/4999 | Win count 184.0
# Epoch 231/4999 | Win count 164.0
# Epoch 232/4999 | Win count 165.0
# Epoch 233/4999 | Win count 176.0
# Epoch 234/4999 | Win count 178.0
# Epoch 235/4999 | Win count 161.0
# Epoch 236/4999 | Win count 178.0
# Epoch 237/4999 | Win count 172.0
# Epoch 238/4999 | Win count 173.0
# Epoch 239/4999 | Win count 185.0
# Epoch 240/4999 | Win count 159.0
# Epoch 241/4999 | Win count 155.0
# Epoch 242/4999 | Win count 170.0
# Epoch 243/4999 | Win count 183.0
# Epoch 244/4999 | Win count 184.0
# Epoch 245/4999 | Win count 177.0
# Epoch 246/4999 | Win count 159.0
# Epoch 247/4999 | Win count 170.0
# Epoch 248/4999 | Win count 170.0
# Epoch 249/4999 | Win count 179.0
# Epoch 250/4999 | Win count 178.0
# Epoch 251/4999 | Win count 179.0
# Epoch 252/4999 | Win count 159.0
# Epoch 253/4999 | Win count 163.0
# Epoch 254/4999 | Win count 192.0
# Epoch 255/4999 | Win count 186.0
# Epoch 256/4999 | Win count 174.0
# Epoch 257/4999 | Win count 159.0
# Epoch 258/4999 | Win count 181.0
# Epoch 259/4999 | Win count 187.0
# Epoch 260/4999 | Win count 152.0
# Epoch 261/4999 | Win count 182.0
# Epoch 262/4999 | Win count 210.0
# Epoch 263/4999 | Win count 185.0
# Epoch 264/4999 | Win count 152.0
# Epoch 265/4999 | Win count 176.0
# Epoch 266/4999 | Win count 161.0
# Epoch 267/4999 | Win count 169.0
# Epoch 268/4999 | Win count 180.0
# Epoch 269/4999 | Win count 157.0
# Epoch 270/4999 | Win count 167.0
# Epoch 271/4999 | Win count 159.0
# Epoch 272/4999 | Win count 180.0
# Epoch 273/4999 | Win count 176.0
# Epoch 274/4999 | Win count 176.0
# Epoch 275/4999 | Win count 177.0
# Epoch 276/4999 | Win count 182.0
# Epoch 277/4999 | Win count 183.0
# Epoch 278/4999 | Win count 164.0
# Epoch 279/4999 | Win count 177.0
# Epoch 280/4999 | Win count 189.0
# Epoch 281/4999 | Win count 162.0
# Epoch 282/4999 | Win count 172.0
# Epoch 283/4999 | Win count 146.0
# Epoch 284/4999 | Win count 189.0
# Epoch 285/4999 | Win count 191.0
# Epoch 286/4999 | Win count 180.0
# Epoch 287/4999 | Win count 194.0
# Epoch 288/4999 | Win count 170.0
# Epoch 289/4999 | Win count 184.0
# Epoch 290/4999 | Win count 177.0
# Epoch 291/4999 | Win count 177.0
# Epoch 292/4999 | Win count 182.0
# Epoch 293/4999 | Win count 161.0
# Epoch 294/4999 | Win count 175.0
# Epoch 295/4999 | Win count 185.0
# Epoch 296/4999 | Win count 173.0
# Epoch 297/4999 | Win count 171.0
# Epoch 298/4999 | Win count 171.0
# Epoch 299/4999 | Win count 179.0
# Epoch 300/4999 | Win count 158.0
# Epoch 301/4999 | Win count 148.0
# Epoch 302/4999 | Win count 172.0
# Epoch 303/4999 | Win count 178.0
# Epoch 304/4999 | Win count 160.0
# Epoch 305/4999 | Win count 169.0
# Epoch 306/4999 | Win count 166.0
# Epoch 307/4999 | Win count 164.0
# Epoch 308/4999 | Win count 180.0
# Epoch 309/4999 | Win count 179.0
# Epoch 310/4999 | Win count 180.0
# Epoch 311/4999 | Win count 188.0
# Epoch 312/4999 | Win count 177.0
# Epoch 313/4999 | Win count 177.0
# Epoch 314/4999 | Win count 183.0
# Epoch 315/4999 | Win count 170.0
# Epoch 316/4999 | Win count 183.0
# Epoch 317/4999 | Win count 206.0
# Epoch 318/4999 | Win count 164.0
# Epoch 319/4999 | Win count 174.0
# Epoch 320/4999 | Win count 185.0
# Epoch 321/4999 | Win count 172.0
# Epoch 322/4999 | Win count 181.0
# Epoch 323/4999 | Win count 182.0
# Epoch 324/4999 | Win count 175.0
# Epoch 325/4999 | Win count 175.0
# Epoch 326/4999 | Win count 182.0
# Epoch 327/4999 | Win count 181.0
# Epoch 328/4999 | Win count 159.0
# Epoch 329/4999 | Win count 181.0
# Epoch 330/4999 | Win count 172.0
# Epoch 331/4999 | Win count 186.0
# Epoch 332/4999 | Win count 183.0
# Epoch 333/4999 | Win count 182.0
# Epoch 334/4999 | Win count 183.0
# Epoch 335/4999 | Win count 190.0
# Epoch 336/4999 | Win count 179.0
# Epoch 337/4999 | Win count 193.0
# Epoch 338/4999 | Win count 175.0
# Epoch 339/4999 | Win count 173.0
# Epoch 340/4999 | Win count 166.0
# Epoch 341/4999 | Win count 188.0
# Epoch 342/4999 | Win count 177.0
# Epoch 343/4999 | Win count 170.0
# Epoch 344/4999 | Win count 172.0
# Epoch 345/4999 | Win count 174.0
# Epoch 346/4999 | Win count 180.0
# Epoch 347/4999 | Win count 174.0
# Epoch 348/4999 | Win count 183.0
# Epoch 349/4999 | Win count 166.0
# Epoch 350/4999 | Win count 190.0
# Epoch 351/4999 | Win count 192.0
# Epoch 352/4999 | Win count 169.0
# Epoch 353/4999 | Win count 177.0
# Epoch 354/4999 | Win count 170.0
# Epoch 355/4999 | Win count 179.0
# Epoch 356/4999 | Win count 177.0
# Epoch 357/4999 | Win count 189.0
# Epoch 358/4999 | Win count 182.0
# Epoch 359/4999 | Win count 185.0
# Epoch 360/4999 | Win count 167.0
# Epoch 361/4999 | Win count 180.0
# Epoch 362/4999 | Win count 182.0
# Epoch 363/4999 | Win count 172.0
# Epoch 364/4999 | Win count 182.0
# Epoch 365/4999 | Win count 186.0
# Epoch 366/4999 | Win count 186.0
# Epoch 367/4999 | Win count 183.0
# Epoch 368/4999 | Win count 177.0
# Epoch 369/4999 | Win count 179.0
# Epoch 370/4999 | Win count 177.0
# Epoch 371/4999 | Win count 176.0
# Epoch 372/4999 | Win count 151.0
# Epoch 373/4999 | Win count 185.0
# Epoch 374/4999 | Win count 159.0
# Epoch 375/4999 | Win count 191.0
# Epoch 376/4999 | Win count 194.0
# Epoch 377/4999 | Win count 177.0
# Epoch 378/4999 | Win count 182.0
# Epoch 379/4999 | Win count 168.0
# Epoch 380/4999 | Win count 189.0
# Epoch 381/4999 | Win count 192.0
# Epoch 382/4999 | Win count 151.0
# Epoch 383/4999 | Win count 181.0
# Epoch 384/4999 | Win count 163.0
# Epoch 385/4999 | Win count 187.0
# Epoch 386/4999 | Win count 206.0
# Epoch 387/4999 | Win count 195.0
# Epoch 388/4999 | Win count 189.0
# Epoch 389/4999 | Win count 180.0
# Epoch 390/4999 | Win count 167.0
# Epoch 391/4999 | Win count 180.0
# Epoch 392/4999 | Win count 182.0
# Epoch 393/4999 | Win count 172.0
# Epoch 394/4999 | Win count 187.0
# Epoch 395/4999 | Win count 179.0
# Epoch 396/4999 | Win count 180.0
# Epoch 397/4999 | Win count 183.0
# Epoch 398/4999 | Win count 176.0
# Epoch 399/4999 | Win count 189.0
# Epoch 400/4999 | Win count 176.0
# Epoch 401/4999 | Win count 156.0
# Epoch 402/4999 | Win count 159.0
# Epoch 403/4999 | Win count 169.0
# Epoch 404/4999 | Win count 171.0
# Epoch 405/4999 | Win count 182.0
# Epoch 406/4999 | Win count 186.0
# Epoch 407/4999 | Win count 171.0
# Epoch 408/4999 | Win count 183.0
# Epoch 409/4999 | Win count 188.0
# Epoch 410/4999 | Win count 178.0
# Epoch 411/4999 | Win count 175.0
# Epoch 412/4999 | Win count 188.0
# Epoch 413/4999 | Win count 172.0
# Epoch 414/4999 | Win count 194.0
# Epoch 415/4999 | Win count 182.0
# Epoch 416/4999 | Win count 189.0
# Epoch 417/4999 | Win count 191.0
# Epoch 418/4999 | Win count 180.0
# Epoch 419/4999 | Win count 188.0
# Epoch 420/4999 | Win count 189.0
# Epoch 421/4999 | Win count 181.0
# Epoch 422/4999 | Win count 185.0
# Epoch 423/4999 | Win count 173.0
# Epoch 424/4999 | Win count 184.0
# Epoch 425/4999 | Win count 191.0
# Epoch 426/4999 | Win count 189.0
# Epoch 427/4999 | Win count 181.0
# Epoch 428/4999 | Win count 183.0
# Epoch 429/4999 | Win count 201.0
# Epoch 430/4999 | Win count 184.0
# Epoch 431/4999 | Win count 173.0
# Epoch 432/4999 | Win count 173.0
# Epoch 433/4999 | Win count 187.0
# Epoch 434/4999 | Win count 185.0
# Epoch 435/4999 | Win count 164.0
# Epoch 436/4999 | Win count 189.0
# Epoch 437/4999 | Win count 177.0
# Epoch 438/4999 | Win count 187.0
# Epoch 439/4999 | Win count 186.0
# Epoch 440/4999 | Win count 168.0
# Epoch 441/4999 | Win count 169.0
# Epoch 442/4999 | Win count 208.0
# Epoch 443/4999 | Win count 192.0
# Epoch 444/4999 | Win count 170.0
# Epoch 445/4999 | Win count 188.0
# Epoch 446/4999 | Win count 204.0
# Epoch 447/4999 | Win count 169.0
# Epoch 448/4999 | Win count 196.0
# Epoch 449/4999 | Win count 172.0
# Epoch 450/4999 | Win count 175.0
# Epoch 451/4999 | Win count 197.0
# Epoch 452/4999 | Win count 208.0
# Epoch 453/4999 | Win count 168.0
# Epoch 454/4999 | Win count 191.0
# Epoch 455/4999 | Win count 184.0
# Epoch 456/4999 | Win count 192.0
# Epoch 457/4999 | Win count 174.0
# Epoch 458/4999 | Win count 176.0
# Epoch 459/4999 | Win count 173.0
# Epoch 460/4999 | Win count 184.0
# Epoch 461/4999 | Win count 178.0
# Epoch 462/4999 | Win count 174.0
# Epoch 463/4999 | Win count 186.0
# Epoch 464/4999 | Win count 179.0
# Epoch 465/4999 | Win count 167.0
# Epoch 466/4999 | Win count 177.0
# Epoch 467/4999 | Win count 193.0
# Epoch 468/4999 | Win count 176.0
# Epoch 469/4999 | Win count 164.0
# Epoch 470/4999 | Win count 188.0
# Epoch 471/4999 | Win count 182.0
# Epoch 472/4999 | Win count 168.0
# Epoch 473/4999 | Win count 186.0
# Epoch 474/4999 | Win count 174.0
# Epoch 475/4999 | Win count 183.0
# Epoch 476/4999 | Win count 193.0
# Epoch 477/4999 | Win count 187.0
# Epoch 478/4999 | Win count 177.0
# Epoch 479/4999 | Win count 178.0
# Epoch 480/4999 | Win count 167.0
# Epoch 481/4999 | Win count 206.0
# Epoch 482/4999 | Win count 188.0
# Epoch 483/4999 | Win count 181.0
# Epoch 484/4999 | Win count 191.0
# Epoch 485/4999 | Win count 191.0
# Epoch 486/4999 | Win count 161.0
# Epoch 487/4999 | Win count 216.0
# Epoch 488/4999 | Win count 178.0
# Epoch 489/4999 | Win count 187.0
# Epoch 490/4999 | Win count 185.0
# Epoch 491/4999 | Win count 217.0
# Epoch 492/4999 | Win count 200.0
# Epoch 493/4999 | Win count 194.0
# Epoch 494/4999 | Win count 173.0
# Epoch 495/4999 | Win count 186.0
# Epoch 496/4999 | Win count 186.0
# Epoch 497/4999 | Win count 185.0
# Epoch 498/4999 | Win count 200.0
# Epoch 499/4999 | Win count 196.0
# Epoch 500/4999 | Win count 213.0
# Epoch 501/4999 | Win count 195.0
# Epoch 502/4999 | Win count 189.0
# Epoch 503/4999 | Win count 170.0
# Epoch 504/4999 | Win count 201.0
# Epoch 505/4999 | Win count 175.0
# Epoch 506/4999 | Win count 196.0
# Epoch 507/4999 | Win count 178.0
# Epoch 508/4999 | Win count 180.0
# Epoch 509/4999 | Win count 183.0
# Epoch 510/4999 | Win count 194.0
# Epoch 511/4999 | Win count 186.0
# Epoch 512/4999 | Win count 190.0
# Epoch 513/4999 | Win count 180.0
# Epoch 514/4999 | Win count 177.0
# Epoch 515/4999 | Win count 202.0
# Epoch 516/4999 | Win count 198.0
# Epoch 517/4999 | Win count 210.0
# Epoch 518/4999 | Win count 169.0
# Epoch 519/4999 | Win count 176.0
# Epoch 520/4999 | Win count 173.0
# Epoch 521/4999 | Win count 202.0
# Epoch 522/4999 | Win count 198.0
# Epoch 523/4999 | Win count 174.0
# Epoch 524/4999 | Win count 181.0
# Epoch 525/4999 | Win count 184.0
# Epoch 526/4999 | Win count 197.0
# Epoch 527/4999 | Win count 201.0
# Epoch 528/4999 | Win count 204.0
# Epoch 529/4999 | Win count 209.0
# Epoch 530/4999 | Win count 192.0
# Epoch 531/4999 | Win count 180.0
# Epoch 532/4999 | Win count 194.0
# Epoch 533/4999 | Win count 168.0
# Epoch 534/4999 | Win count 220.0
# Epoch 535/4999 | Win count 184.0
# Epoch 536/4999 | Win count 211.0
# Epoch 537/4999 | Win count 188.0
# Epoch 538/4999 | Win count 203.0
# Epoch 539/4999 | Win count 196.0
# Epoch 540/4999 | Win count 195.0
# Epoch 541/4999 | Win count 190.0
# Epoch 542/4999 | Win count 200.0
# Epoch 543/4999 | Win count 189.0
# Epoch 544/4999 | Win count 174.0
# Epoch 545/4999 | Win count 180.0
# Epoch 546/4999 | Win count 200.0
# Epoch 547/4999 | Win count 197.0
# Epoch 548/4999 | Win count 203.0
# Epoch 549/4999 | Win count 204.0
# Epoch 550/4999 | Win count 196.0
# Epoch 551/4999 | Win count 197.0
# Epoch 552/4999 | Win count 195.0
# Epoch 553/4999 | Win count 204.0
# Epoch 554/4999 | Win count 205.0
# Epoch 555/4999 | Win count 187.0
# Epoch 556/4999 | Win count 186.0
# Epoch 557/4999 | Win count 191.0
# Epoch 558/4999 | Win count 188.0
# Epoch 559/4999 | Win count 218.0
# Epoch 560/4999 | Win count 193.0
# Epoch 561/4999 | Win count 184.0
# Epoch 562/4999 | Win count 189.0
# Epoch 563/4999 | Win count 198.0
# Epoch 564/4999 | Win count 195.0
# Epoch 565/4999 | Win count 193.0
# Epoch 566/4999 | Win count 178.0
# Epoch 567/4999 | Win count 206.0
# Epoch 568/4999 | Win count 222.0
# Epoch 569/4999 | Win count 160.0
# Epoch 570/4999 | Win count 189.0
# Epoch 571/4999 | Win count 177.0
# Epoch 572/4999 | Win count 176.0
# Epoch 573/4999 | Win count 177.0
# Epoch 574/4999 | Win count 207.0
# Epoch 575/4999 | Win count 186.0
# Epoch 576/4999 | Win count 200.0
# Epoch 577/4999 | Win count 191.0
# Epoch 578/4999 | Win count 197.0
# Epoch 579/4999 | Win count 187.0
# Epoch 580/4999 | Win count 189.0
# Epoch 581/4999 | Win count 201.0
# Epoch 582/4999 | Win count 181.0
# Epoch 583/4999 | Win count 188.0
# Epoch 584/4999 | Win count 216.0
# Epoch 585/4999 | Win count 201.0
# Epoch 586/4999 | Win count 187.0
# Epoch 587/4999 | Win count 189.0
# Epoch 588/4999 | Win count 199.0
# Epoch 589/4999 | Win count 201.0
# Epoch 590/4999 | Win count 200.0
# Epoch 591/4999 | Win count 191.0
# Epoch 592/4999 | Win count 190.0
# Epoch 593/4999 | Win count 210.0
# Epoch 594/4999 | Win count 202.0
# Epoch 595/4999 | Win count 200.0
# Epoch 596/4999 | Win count 170.0
# Epoch 597/4999 | Win count 200.0
# Epoch 598/4999 | Win count 185.0
# Epoch 599/4999 | Win count 193.0
# Epoch 600/4999 | Win count 207.0
# Epoch 601/4999 | Win count 215.0
# Epoch 602/4999 | Win count 203.0
# Epoch 603/4999 | Win count 210.0
# Epoch 604/4999 | Win count 211.0
# Epoch 605/4999 | Win count 185.0
# Epoch 606/4999 | Win count 198.0
# Epoch 607/4999 | Win count 223.0
# Epoch 608/4999 | Win count 194.0
# Epoch 609/4999 | Win count 194.0
# Epoch 610/4999 | Win count 192.0
# Epoch 611/4999 | Win count 208.0
# Epoch 612/4999 | Win count 198.0
# Epoch 613/4999 | Win count 192.0
# Epoch 614/4999 | Win count 214.0
# Epoch 615/4999 | Win count 208.0
# Epoch 616/4999 | Win count 212.0
# Epoch 617/4999 | Win count 191.0
# Epoch 618/4999 | Win count 175.0
# Epoch 619/4999 | Win count 227.0
# Epoch 620/4999 | Win count 192.0
# Epoch 621/4999 | Win count 194.0
# Epoch 622/4999 | Win count 203.0
# Epoch 623/4999 | Win count 210.0
# Epoch 624/4999 | Win count 199.0
# Epoch 625/4999 | Win count 205.0
# Epoch 626/4999 | Win count 190.0
# Epoch 627/4999 | Win count 196.0
# Epoch 628/4999 | Win count 206.0
# Epoch 629/4999 | Win count 218.0
# Epoch 630/4999 | Win count 202.0
# Epoch 631/4999 | Win count 212.0
# Epoch 632/4999 | Win count 190.0
# Epoch 633/4999 | Win count 203.0
# Epoch 634/4999 | Win count 182.0
# Epoch 635/4999 | Win count 200.0
# Epoch 636/4999 | Win count 194.0
# Epoch 637/4999 | Win count 205.0
# Epoch 638/4999 | Win count 201.0
# Epoch 639/4999 | Win count 195.0
# Epoch 640/4999 | Win count 206.0
# Epoch 641/4999 | Win count 209.0
# Epoch 642/4999 | Win count 208.0
# Epoch 643/4999 | Win count 201.0
# Epoch 644/4999 | Win count 212.0
# Epoch 645/4999 | Win count 198.0
# Epoch 646/4999 | Win count 192.0
# Epoch 647/4999 | Win count 215.0
# Epoch 648/4999 | Win count 221.0
# Epoch 649/4999 | Win count 191.0
# Epoch 650/4999 | Win count 191.0
# Epoch 651/4999 | Win count 208.0
# Epoch 652/4999 | Win count 198.0
# Epoch 653/4999 | Win count 218.0
# Epoch 654/4999 | Win count 200.0
# Epoch 655/4999 | Win count 212.0
# Epoch 656/4999 | Win count 204.0
# Epoch 657/4999 | Win count 209.0
# Epoch 658/4999 | Win count 224.0
# Epoch 659/4999 | Win count 205.0
# Epoch 660/4999 | Win count 224.0
# Epoch 661/4999 | Win count 213.0
# Epoch 662/4999 | Win count 201.0
# Epoch 663/4999 | Win count 222.0
# Epoch 664/4999 | Win count 207.0
# Epoch 665/4999 | Win count 222.0
# Epoch 666/4999 | Win count 196.0
# Epoch 667/4999 | Win count 205.0
# Epoch 668/4999 | Win count 230.0
# Epoch 669/4999 | Win count 217.0
# Epoch 670/4999 | Win count 201.0
# Epoch 671/4999 | Win count 194.0
# Epoch 672/4999 | Win count 220.0
# Epoch 673/4999 | Win count 186.0
# Epoch 674/4999 | Win count 238.0
# Epoch 675/4999 | Win count 221.0
# Epoch 676/4999 | Win count 202.0
# Epoch 677/4999 | Win count 212.0
# Epoch 678/4999 | Win count 193.0
# Epoch 679/4999 | Win count 206.0
# Epoch 680/4999 | Win count 244.0
# Epoch 681/4999 | Win count 216.0
# Epoch 682/4999 | Win count 211.0
# Epoch 683/4999 | Win count 217.0
# Epoch 684/4999 | Win count 219.0
# Epoch 685/4999 | Win count 205.0
# Epoch 686/4999 | Win count 219.0
# Epoch 687/4999 | Win count 192.0
# Epoch 688/4999 | Win count 233.0
# Epoch 689/4999 | Win count 209.0
# Epoch 690/4999 | Win count 241.0
# Epoch 691/4999 | Win count 222.0
# Epoch 692/4999 | Win count 213.0
# Epoch 693/4999 | Win count 213.0
# Epoch 694/4999 | Win count 205.0
# Epoch 695/4999 | Win count 213.0
# Epoch 696/4999 | Win count 210.0
# Epoch 697/4999 | Win count 208.0
# Epoch 698/4999 | Win count 219.0
# Epoch 699/4999 | Win count 225.0
# Epoch 700/4999 | Win count 196.0
# Epoch 701/4999 | Win count 198.0
# Epoch 702/4999 | Win count 231.0
# Epoch 703/4999 | Win count 227.0
# Epoch 704/4999 | Win count 225.0
# Epoch 705/4999 | Win count 229.0
# Epoch 706/4999 | Win count 232.0
# Epoch 707/4999 | Win count 225.0
# Epoch 708/4999 | Win count 205.0
# Epoch 709/4999 | Win count 217.0
# Epoch 710/4999 | Win count 224.0
# Epoch 711/4999 | Win count 212.0
# Epoch 712/4999 | Win count 208.0
# Epoch 713/4999 | Win count 202.0
# Epoch 714/4999 | Win count 206.0
# Epoch 715/4999 | Win count 210.0
# Epoch 716/4999 | Win count 190.0
# Epoch 717/4999 | Win count 206.0
# Epoch 718/4999 | Win count 232.0
# Epoch 719/4999 | Win count 234.0
# Epoch 720/4999 | Win count 203.0
# Epoch 721/4999 | Win count 208.0
# Epoch 722/4999 | Win count 238.0
# Epoch 723/4999 | Win count 256.0
# Epoch 724/4999 | Win count 212.0
# Epoch 725/4999 | Win count 224.0
# Epoch 726/4999 | Win count 219.0
# Epoch 727/4999 | Win count 237.0
# Epoch 728/4999 | Win count 234.0
# Epoch 729/4999 | Win count 206.0
# Epoch 730/4999 | Win count 224.0
# Epoch 731/4999 | Win count 225.0
# Epoch 732/4999 | Win count 228.0
# Epoch 733/4999 | Win count 228.0
# Epoch 734/4999 | Win count 217.0
# Epoch 735/4999 | Win count 217.0
# Epoch 736/4999 | Win count 209.0
# Epoch 737/4999 | Win count 224.0
# Epoch 738/4999 | Win count 218.0
# Epoch 739/4999 | Win count 239.0
# Epoch 740/4999 | Win count 195.0
# Epoch 741/4999 | Win count 237.0
# Epoch 742/4999 | Win count 236.0
# Epoch 743/4999 | Win count 207.0
# Epoch 744/4999 | Win count 225.0
# Epoch 745/4999 | Win count 238.0
# Epoch 746/4999 | Win count 247.0
# Epoch 747/4999 | Win count 207.0
# Epoch 748/4999 | Win count 217.0
# Epoch 749/4999 | Win count 216.0
# Epoch 750/4999 | Win count 234.0
# Epoch 751/4999 | Win count 243.0
# Epoch 752/4999 | Win count 222.0
# Epoch 753/4999 | Win count 234.0
# Epoch 754/4999 | Win count 222.0
# Epoch 755/4999 | Win count 228.0
# Epoch 756/4999 | Win count 232.0
# Epoch 757/4999 | Win count 231.0
# Epoch 758/4999 | Win count 232.0
# Epoch 759/4999 | Win count 197.0
# Epoch 760/4999 | Win count 199.0
# Epoch 761/4999 | Win count 203.0
# Epoch 762/4999 | Win count 218.0
# Epoch 763/4999 | Win count 250.0
# Epoch 764/4999 | Win count 258.0
# Epoch 765/4999 | Win count 230.0
# Epoch 766/4999 | Win count 224.0
# Epoch 767/4999 | Win count 226.0
# Epoch 768/4999 | Win count 230.0
# Epoch 769/4999 | Win count 221.0
# Epoch 770/4999 | Win count 252.0
# Epoch 771/4999 | Win count 233.0
# Epoch 772/4999 | Win count 258.0
# Epoch 773/4999 | Win count 230.0
# Epoch 774/4999 | Win count 220.0
# Epoch 775/4999 | Win count 222.0
# Epoch 776/4999 | Win count 214.0
# Epoch 777/4999 | Win count 228.0
# Epoch 778/4999 | Win count 247.0
# Epoch 779/4999 | Win count 235.0
# Epoch 780/4999 | Win count 218.0
# Epoch 781/4999 | Win count 230.0
# Epoch 782/4999 | Win count 243.0
# Epoch 783/4999 | Win count 244.0
# Epoch 784/4999 | Win count 249.0
# Epoch 785/4999 | Win count 259.0
# Epoch 786/4999 | Win count 241.0
# Epoch 787/4999 | Win count 222.0
# Epoch 788/4999 | Win count 230.0
# Epoch 789/4999 | Win count 231.0
# Epoch 790/4999 | Win count 233.0
# Epoch 791/4999 | Win count 241.0
# Epoch 792/4999 | Win count 233.0
# Epoch 793/4999 | Win count 244.0
# Epoch 794/4999 | Win count 229.0
# Epoch 795/4999 | Win count 229.0
# Epoch 796/4999 | Win count 234.0
# Epoch 797/4999 | Win count 236.0
# Epoch 798/4999 | Win count 229.0
# Epoch 799/4999 | Win count 221.0
# Epoch 800/4999 | Win count 224.0
# Epoch 801/4999 | Win count 230.0
# Epoch 802/4999 | Win count 234.0
# Epoch 803/4999 | Win count 234.0
# Epoch 804/4999 | Win count 244.0
# Epoch 805/4999 | Win count 245.0
# Epoch 806/4999 | Win count 257.0
# Epoch 807/4999 | Win count 238.0
# Epoch 808/4999 | Win count 222.0
# Epoch 809/4999 | Win count 247.0
# Epoch 810/4999 | Win count 214.0
# Epoch 811/4999 | Win count 216.0
# Epoch 812/4999 | Win count 237.0
# Epoch 813/4999 | Win count 233.0
# Epoch 814/4999 | Win count 226.0
# Epoch 815/4999 | Win count 243.0
# Epoch 816/4999 | Win count 226.0
# Epoch 817/4999 | Win count 241.0
# Epoch 818/4999 | Win count 247.0
# Epoch 819/4999 | Win count 222.0
# Epoch 820/4999 | Win count 225.0
# Epoch 821/4999 | Win count 251.0
# Epoch 822/4999 | Win count 240.0
# Epoch 823/4999 | Win count 236.0
# Epoch 824/4999 | Win count 238.0
# Epoch 825/4999 | Win count 229.0
# Epoch 826/4999 | Win count 218.0
# Epoch 827/4999 | Win count 228.0
# Epoch 828/4999 | Win count 252.0
# Epoch 829/4999 | Win count 241.0
# Epoch 830/4999 | Win count 236.0
# Epoch 831/4999 | Win count 236.0
# Epoch 832/4999 | Win count 259.0
# Epoch 833/4999 | Win count 241.0
# Epoch 834/4999 | Win count 228.0
# Epoch 835/4999 | Win count 252.0
# Epoch 836/4999 | Win count 229.0
# Epoch 837/4999 | Win count 250.0
# Epoch 838/4999 | Win count 249.0
# Epoch 839/4999 | Win count 274.0
# Epoch 840/4999 | Win count 238.0
# Epoch 841/4999 | Win count 220.0
# Epoch 842/4999 | Win count 233.0
# Epoch 843/4999 | Win count 232.0
# Epoch 844/4999 | Win count 246.0
# Epoch 845/4999 | Win count 233.0
# Epoch 846/4999 | Win count 248.0
# Epoch 847/4999 | Win count 229.0
# Epoch 848/4999 | Win count 222.0
# Epoch 849/4999 | Win count 250.0
# Epoch 850/4999 | Win count 249.0
# Epoch 851/4999 | Win count 242.0
# Epoch 852/4999 | Win count 251.0
# Epoch 853/4999 | Win count 261.0
# Epoch 854/4999 | Win count 234.0
# Epoch 855/4999 | Win count 239.0
# Epoch 856/4999 | Win count 246.0
# Epoch 857/4999 | Win count 229.0
# Epoch 858/4999 | Win count 252.0
# Epoch 859/4999 | Win count 247.0
# Epoch 860/4999 | Win count 239.0
# Epoch 861/4999 | Win count 251.0
# Epoch 862/4999 | Win count 237.0
# Epoch 863/4999 | Win count 248.0
# Epoch 864/4999 | Win count 252.0
# Epoch 865/4999 | Win count 235.0
# Epoch 866/4999 | Win count 233.0
# Epoch 867/4999 | Win count 238.0
# Epoch 868/4999 | Win count 252.0
# Epoch 869/4999 | Win count 246.0
# Epoch 870/4999 | Win count 242.0
# Epoch 871/4999 | Win count 230.0
# Epoch 872/4999 | Win count 232.0
# Epoch 873/4999 | Win count 245.0
# Epoch 874/4999 | Win count 231.0
# Epoch 875/4999 | Win count 238.0
# Epoch 876/4999 | Win count 237.0
# Epoch 877/4999 | Win count 235.0
# Epoch 878/4999 | Win count 254.0
# Epoch 879/4999 | Win count 258.0
# Epoch 880/4999 | Win count 251.0
# Epoch 881/4999 | Win count 249.0
# Epoch 882/4999 | Win count 222.0
# Epoch 883/4999 | Win count 240.0
# Epoch 884/4999 | Win count 253.0
# Epoch 885/4999 | Win count 249.0
# Epoch 886/4999 | Win count 242.0
# Epoch 887/4999 | Win count 250.0
# Epoch 888/4999 | Win count 247.0
# Epoch 889/4999 | Win count 244.0
# Epoch 890/4999 | Win count 229.0
# Epoch 891/4999 | Win count 259.0
# Epoch 892/4999 | Win count 241.0
# Epoch 893/4999 | Win count 251.0
# Epoch 894/4999 | Win count 260.0
# Epoch 895/4999 | Win count 244.0
# Epoch 896/4999 | Win count 216.0
# Epoch 897/4999 | Win count 233.0
# Epoch 898/4999 | Win count 239.0
# Epoch 899/4999 | Win count 253.0
# Epoch 900/4999 | Win count 239.0
# Epoch 901/4999 | Win count 252.0
# Epoch 902/4999 | Win count 262.0
# Epoch 903/4999 | Win count 254.0
# Epoch 904/4999 | Win count 255.0
# Epoch 905/4999 | Win count 236.0
# Epoch 906/4999 | Win count 240.0
# Epoch 907/4999 | Win count 259.0
# Epoch 908/4999 | Win count 272.0
# Epoch 909/4999 | Win count 245.0
# Epoch 910/4999 | Win count 217.0
# Epoch 911/4999 | Win count 237.0
# Epoch 912/4999 | Win count 237.0
# Epoch 913/4999 | Win count 259.0
# Epoch 914/4999 | Win count 257.0
# Epoch 915/4999 | Win count 251.0
# Epoch 916/4999 | Win count 266.0
# Epoch 917/4999 | Win count 244.0
# Epoch 918/4999 | Win count 250.0
# Epoch 919/4999 | Win count 274.0
# Epoch 920/4999 | Win count 256.0
# Epoch 921/4999 | Win count 241.0
# Epoch 922/4999 | Win count 246.0
# Epoch 923/4999 | Win count 243.0
# Epoch 924/4999 | Win count 256.0
# Epoch 925/4999 | Win count 255.0
# Epoch 926/4999 | Win count 255.0
# Epoch 927/4999 | Win count 249.0
# Epoch 928/4999 | Win count 248.0
# Epoch 929/4999 | Win count 255.0
# Epoch 930/4999 | Win count 232.0
# Epoch 931/4999 | Win count 251.0
# Epoch 932/4999 | Win count 257.0
# Epoch 933/4999 | Win count 247.0
# Epoch 934/4999 | Win count 257.0
# Epoch 935/4999 | Win count 251.0
# Epoch 936/4999 | Win count 255.0
# Epoch 937/4999 | Win count 257.0
# Epoch 938/4999 | Win count 239.0
# Epoch 939/4999 | Win count 258.0
# Epoch 940/4999 | Win count 269.0
# Epoch 941/4999 | Win count 239.0
# Epoch 942/4999 | Win count 240.0
# Epoch 943/4999 | Win count 258.0
# Epoch 944/4999 | Win count 285.0
# Epoch 945/4999 | Win count 269.0
# Epoch 946/4999 | Win count 268.0
# Epoch 947/4999 | Win count 259.0
# Epoch 948/4999 | Win count 267.0
# Epoch 949/4999 | Win count 266.0
# Epoch 950/4999 | Win count 262.0
# Epoch 951/4999 | Win count 258.0
# Epoch 952/4999 | Win count 249.0
# Epoch 953/4999 | Win count 258.0
# Epoch 954/4999 | Win count 272.0
# Epoch 955/4999 | Win count 282.0
# Epoch 956/4999 | Win count 265.0
# Epoch 957/4999 | Win count 267.0
# Epoch 958/4999 | Win count 283.0
# Epoch 959/4999 | Win count 271.0
# Epoch 960/4999 | Win count 250.0
# Epoch 961/4999 | Win count 271.0
# Epoch 962/4999 | Win count 268.0
# Epoch 963/4999 | Win count 274.0
# Epoch 964/4999 | Win count 269.0
# Epoch 965/4999 | Win count 275.0
# Epoch 966/4999 | Win count 265.0
# Epoch 967/4999 | Win count 266.0
# Epoch 968/4999 | Win count 261.0
# Epoch 969/4999 | Win count 265.0
# Epoch 970/4999 | Win count 267.0
# Epoch 971/4999 | Win count 256.0
# Epoch 972/4999 | Win count 263.0
# Epoch 973/4999 | Win count 264.0
# Epoch 974/4999 | Win count 301.0
# Epoch 975/4999 | Win count 265.0
# Epoch 976/4999 | Win count 278.0
# Epoch 977/4999 | Win count 268.0
# Epoch 978/4999 | Win count 279.0
# Epoch 979/4999 | Win count 297.0
# Epoch 980/4999 | Win count 259.0
# Epoch 981/4999 | Win count 279.0
# Epoch 982/4999 | Win count 291.0
# Epoch 983/4999 | Win count 272.0
# Epoch 984/4999 | Win count 282.0
# Epoch 985/4999 | Win count 270.0
# Epoch 986/4999 | Win count 268.0
# Epoch 4597/4999 | Win count 438.0
# Epoch 4598/4999 | Win count 435.0
# Epoch 4599/4999 | Win count 448.0
# Epoch 4600/4999 | Win count 436.0
# Epoch 4601/4999 | Win count 448.0
# Epoch 4602/4999 | Win count 437.0
# Epoch 4603/4999 | Win count 456.0
# Epoch 4604/4999 | Win count 440.0
# Epoch 4605/4999 | Win count 444.0
# Epoch 4606/4999 | Win count 431.0
# Epoch 4607/4999 | Win count 435.0
# Epoch 4608/4999 | Win count 445.0
# Epoch 4609/4999 | Win count 443.0
# Epoch 4610/4999 | Win count 436.0
# Epoch 4611/4999 | Win count 438.0
# Epoch 4612/4999 | Win count 438.0
# Epoch 4613/4999 | Win count 431.0
# Epoch 4614/4999 | Win count 429.0
# Epoch 4615/4999 | Win count 450.0
# Epoch 4616/4999 | Win count 424.0
# Epoch 4617/4999 | Win count 435.0
# Epoch 4618/4999 | Win count 455.0
# Epoch 4619/4999 | Win count 431.0
# Epoch 4620/4999 | Win count 435.0
# Epoch 4621/4999 | Win count 433.0
# Epoch 4622/4999 | Win count 436.0
# Epoch 4623/4999 | Win count 442.0
# Epoch 4624/4999 | Win count 429.0
# Epoch 4625/4999 | Win count 435.0
# Epoch 4626/4999 | Win count 452.0
# Epoch 4627/4999 | Win count 449.0
# Epoch 4628/4999 | Win count 432.0
# Epoch 4629/4999 | Win count 445.0
# Epoch 4630/4999 | Win count 457.0
# Epoch 4631/4999 | Win count 436.0
# Epoch 4632/4999 | Win count 452.0
# Epoch 4633/4999 | Win count 451.0
# Epoch 4634/4999 | Win count 439.0
# Epoch 4635/4999 | Win count 444.0
# Epoch 4636/4999 | Win count 432.0
# Epoch 4637/4999 | Win count 447.0
# Epoch 4638/4999 | Win count 427.0
# Epoch 4639/4999 | Win count 453.0
# Epoch 4640/4999 | Win count 452.0
# Epoch 4641/4999 | Win count 436.0
# Epoch 4642/4999 | Win count 443.0
# Epoch 4643/4999 | Win count 445.0
# Epoch 4644/4999 | Win count 440.0
# Epoch 4645/4999 | Win count 450.0
# Epoch 4646/4999 | Win count 438.0
# Epoch 4647/4999 | Win count 447.0
# Epoch 4648/4999 | Win count 428.0
# Epoch 4649/4999 | Win count 450.0
# Epoch 4650/4999 | Win count 426.0
# Epoch 4651/4999 | Win count 442.0
# Epoch 4652/4999 | Win count 449.0
# Epoch 4653/4999 | Win count 445.0
# Epoch 4654/4999 | Win count 436.0
# Epoch 4655/4999 | Win count 438.0
# Epoch 4656/4999 | Win count 424.0
# Epoch 4657/4999 | Win count 445.0
# Epoch 4658/4999 | Win count 431.0
# Epoch 4659/4999 | Win count 430.0
# Epoch 4660/4999 | Win count 436.0
# Epoch 4661/4999 | Win count 442.0
# Epoch 4662/4999 | Win count 439.0
# Epoch 4663/4999 | Win count 439.0
# Epoch 4664/4999 | Win count 446.0
# Epoch 4665/4999 | Win count 442.0
# Epoch 4666/4999 | Win count 456.0
# Epoch 4667/4999 | Win count 426.0
# Epoch 4668/4999 | Win count 437.0
# Epoch 4669/4999 | Win count 442.0
# Epoch 4815/4999 | Win count 441.0
# Epoch 4816/4999 | Win count 441.0
# Epoch 4817/4999 | Win count 428.0
# Epoch 4818/4999 | Win count 442.0
# Epoch 4819/4999 | Win count 435.0
# Epoch 4820/4999 | Win count 442.0
# Epoch 4821/4999 | Win count 443.0
# Epoch 4822/4999 | Win count 429.0
# Epoch 4823/4999 | Win count 442.0
# Epoch 4824/4999 | Win count 448.0
# Epoch 4825/4999 | Win count 450.0
# Epoch 4826/4999 | Win count 460.0
# Epoch 4827/4999 | Win count 442.0
# Epoch 4828/4999 | Win count 447.0
# Epoch 4829/4999 | Win count 438.0
# Epoch 4830/4999 | Win count 439.0
# Epoch 4831/4999 | Win count 445.0
# Epoch 4832/4999 | Win count 446.0
# Epoch 4833/4999 | Win count 437.0
# Epoch 4834/4999 | Win count 451.0
# Epoch 4835/4999 | Win count 442.0
# Epoch 4836/4999 | Win count 455.0
# Epoch 4837/4999 | Win count 434.0
# Epoch 4838/4999 | Win count 438.0
# Epoch 4839/4999 | Win count 436.0
# Epoch 4840/4999 | Win count 436.0
# Epoch 4841/4999 | Win count 430.0
# Epoch 4842/4999 | Win count 438.0
# Epoch 4843/4999 | Win count 452.0
# Epoch 4844/4999 | Win count 436.0
# Epoch 4845/4999 | Win count 440.0
# Epoch 4846/4999 | Win count 441.0
# Epoch 4847/4999 | Win count 430.0
# Epoch 4848/4999 | Win count 432.0
# Epoch 4849/4999 | Win count 435.0
# Epoch 4850/4999 | Win count 446.0
# Epoch 4851/4999 | Win count 450.0
# Epoch 4852/4999 | Win count 438.0
# Epoch 4853/4999 | Win count 454.0
# Epoch 4854/4999 | Win count 447.0
# Epoch 4855/4999 | Win count 434.0
# Epoch 4856/4999 | Win count 432.0
# Epoch 4857/4999 | Win count 429.0
# Epoch 4858/4999 | Win count 430.0
# Epoch 4859/4999 | Win count 443.0
# Epoch 4860/4999 | Win count 432.0
# Epoch 4861/4999 | Win count 440.0
# Epoch 4862/4999 | Win count 440.0
# Epoch 4863/4999 | Win count 438.0
# Epoch 4864/4999 | Win count 440.0
# Epoch 4865/4999 | Win count 455.0
# Epoch 4866/4999 | Win count 438.0
# Epoch 4867/4999 | Win count 436.0
# Epoch 4868/4999 | Win count 439.0
# Epoch 4869/4999 | Win count 446.0
# Epoch 4870/4999 | Win count 437.0
# Epoch 4871/4999 | Win count 446.0
# Epoch 4872/4999 | Win count 439.0
# Epoch 4873/4999 | Win count 455.0
# Epoch 4874/4999 | Win count 436.0
# Epoch 4875/4999 | Win count 438.0
# Epoch 4876/4999 | Win count 436.0
# Epoch 4877/4999 | Win count 433.0
# Epoch 4878/4999 | Win count 458.0
# Epoch 4879/4999 | Win count 439.0
# Epoch 4880/4999 | Win count 448.0
# Epoch 4881/4999 | Win count 425.0
# Epoch 4882/4999 | Win count 444.0
# Epoch 4883/4999 | Win count 434.0
# Epoch 4884/4999 | Win count 441.0
# Epoch 4885/4999 | Win count 447.0
# Epoch 4886/4999 | Win count 434.0
# Epoch 4887/4999 | Win count 446.0
# Epoch 4888/4999 | Win count 447.0
# Epoch 4889/4999 | Win count 433.0
# Epoch 4890/4999 | Win count 443.0
# Epoch 4891/4999 | Win count 454.0
# Epoch 4892/4999 | Win count 446.0
# Epoch 4893/4999 | Win count 441.0
# Epoch 4894/4999 | Win count 443.0
# Epoch 4895/4999 | Win count 434.0
# Epoch 4896/4999 | Win count 436.0
# Epoch 4897/4999 | Win count 439.0
# Epoch 4898/4999 | Win count 442.0
# Epoch 4899/4999 | Win count 443.0
# Epoch 4900/4999 | Win count 448.0
# Epoch 4901/4999 | Win count 439.0
# Epoch 4902/4999 | Win count 437.0
# Epoch 4903/4999 | Win count 443.0
# Epoch 4904/4999 | Win count 444.0
# Epoch 4905/4999 | Win count 444.0
# Epoch 4906/4999 | Win count 446.0
# Epoch 4907/4999 | Win count 439.0
# Epoch 4908/4999 | Win count 437.0
# Epoch 4909/4999 | Win count 448.0
# Epoch 4910/4999 | Win count 445.0
# Epoch 4911/4999 | Win count 450.0
# Epoch 4912/4999 | Win count 440.0
# Epoch 4913/4999 | Win count 448.0
# Epoch 4914/4999 | Win count 436.0
# Epoch 4915/4999 | Win count 440.0
# Epoch 4916/4999 | Win count 442.0
# Epoch 4917/4999 | Win count 439.0
# Epoch 4918/4999 | Win count 438.0
# Epoch 4919/4999 | Win count 453.0
# Epoch 4920/4999 | Win count 446.0
# Epoch 4921/4999 | Win count 438.0
# Epoch 4922/4999 | Win count 441.0
# Epoch 4923/4999 | Win count 435.0
# Epoch 4924/4999 | Win count 449.0
# Epoch 4925/4999 | Win count 441.0
# Epoch 4926/4999 | Win count 434.0
# Epoch 4927/4999 | Win count 454.0
# Epoch 4928/4999 | Win count 437.0
# Epoch 4929/4999 | Win count 430.0
# Epoch 4930/4999 | Win count 446.0
# Epoch 4931/4999 | Win count 445.0
# Epoch 4932/4999 | Win count 440.0
# Epoch 4933/4999 | Win count 439.0
# Epoch 4934/4999 | Win count 436.0
# Epoch 4935/4999 | Win count 444.0
# Epoch 4936/4999 | Win count 442.0
# Epoch 4937/4999 | Win count 443.0
# Epoch 4938/4999 | Win count 428.0
# Epoch 4939/4999 | Win count 441.0
# Epoch 4940/4999 | Win count 460.0
# Epoch 4941/4999 | Win count 438.0
# Epoch 4942/4999 | Win count 426.0
# Epoch 4943/4999 | Win count 440.0
# Epoch 4944/4999 | Win count 442.0
# Epoch 4945/4999 | Win count 433.0
# Epoch 4946/4999 | Win count 431.0
# Epoch 4947/4999 | Win count 427.0
# Epoch 4948/4999 | Win count 431.0
# Epoch 4949/4999 | Win count 442.0
# Epoch 4950/4999 | Win count 439.0
# Epoch 4951/4999 | Win count 437.0
# Epoch 4952/4999 | Win count 447.0
# Epoch 4953/4999 | Win count 439.0
# Epoch 4954/4999 | Win count 440.0
# Epoch 4955/4999 | Win count 455.0
# Epoch 4956/4999 | Win count 437.0
# Epoch 4957/4999 | Win count 436.0
# Epoch 4958/4999 | Win count 452.0
# Epoch 4959/4999 | Win count 439.0
# Epoch 4960/4999 | Win count 448.0
# Epoch 4961/4999 | Win count 440.0
# Epoch 4962/4999 | Win count 458.0
# Epoch 4963/4999 | Win count 436.0
# Epoch 4964/4999 | Win count 443.0
# Epoch 4965/4999 | Win count 449.0
# Epoch 4966/4999 | Win count 447.0
# Epoch 4967/4999 | Win count 446.0
# Epoch 4968/4999 | Win count 420.0
# Epoch 4969/4999 | Win count 443.0
# Epoch 4970/4999 | Win count 443.0
# Epoch 4971/4999 | Win count 438.0
# Epoch 4972/4999 | Win count 440.0
# Epoch 4973/4999 | Win count 446.0
# Epoch 4974/4999 | Win count 449.0
# Epoch 4975/4999 | Win count 449.0
# Epoch 4976/4999 | Win count 443.0
# Epoch 4977/4999 | Win count 437.0
# Epoch 4978/4999 | Win count 449.0
# Epoch 4979/4999 | Win count 439.0
# Epoch 4980/4999 | Win count 426.0
# Epoch 4981/4999 | Win count 453.0
# Epoch 4982/4999 | Win count 447.0
# Epoch 4983/4999 | Win count 441.0
# Epoch 4984/4999 | Win count 446.0
# Epoch 4985/4999 | Win count 437.0
# Epoch 4986/4999 | Win count 449.0
# Epoch 4987/4999 | Win count 447.0
# Epoch 4988/4999 | Win count 437.0
# Epoch 4989/4999 | Win count 439.0
# Epoch 4990/4999 | Win count 445.0
# Epoch 4991/4999 | Win count 441.0
# Epoch 4992/4999 | Win count 435.0
# Epoch 4993/4999 | Win count 435.0
# Epoch 4994/4999 | Win count 440.0
# Epoch 4995/4999 | Win count 440.0
# Epoch 4996/4999 | Win count 443.0
# Epoch 4997/4999 | Win count 445.0
# Epoch 4998/4999 | Win count 434.0
# Epoch 4999/4999 | Win count 445.0
# Training completed!

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import keras
from evolve import Catch

model_from_json = keras.models.model_from_json

if __name__ == "__main__":
    # Make sure this grid size matches the value used fro training
    grid_size = 10

    with open("model.json", "r") as jfile:
        model = model_from_json(json.load(jfile))
    model.load_weights("model.h5")
    model.compile("sgd", "mse")

    # Define environment, game
    env = Catch(grid_size)
    c = 0
    for e in range(10):
        loss = 0.
        env.reset()
        game_over = False
        # get initial input
        input_t = env.observe()

        plt.imshow(input_t.reshape((grid_size,)*2),
                   interpolation='none', cmap='gray')
        plt.axis("off")
        for n in range(5):
            plt.savefig("%04d.png" % c)
            c += 1
        while not game_over:
            input_tm1 = input_t

            # get next action
            q = model.predict(input_tm1)
            action = np.argmax(q[0])

            # apply action, get rewards and new state
            input_t, reward, game_over = env.act(action)

            plt.imshow(input_t.reshape((grid_size,)*2),
                       interpolation='none', cmap='gray')
            plt.axis("off")
            for n in range(5):
                plt.savefig("%04d.png" % c)
                c += 1

print("Prediction and images generation completed!")
# Out:
# Prediction and images generation completed!

# %% [markdown]
# ### Create an animated Gif on Mac OS X with imagemagick (similar on Linux)
#
#     > brew install imagemagick --build-from-source
#     > brew upgrade imagemagick
#     > for f in *.png; do mv "$f" "${f#0}"; done
#     # Note: Take the last 150 images since the agent has learned a lot and plays better.
#     > convert -resize 50% -delay 10 -loop 0 {350..499}.png CatchVideogame_ES_Me.gif
#
# The resulting animated gif image:
#
# <img src="CatchVideogame_ES_Me.gif" width=200>
