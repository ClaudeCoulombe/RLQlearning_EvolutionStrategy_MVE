# %% [markdown]
# # Playing Simple Catch Videogame with RL and QLearning using Keras
# Eder Santana blog post: http://edersantana.github.io/articles/keras_rl/
#
# Eder Santana GitHub gist repo: https://gist.github.com/EderSantana/c7222daa328f0e885093
#
# Small correction and addition of this iPython Notebook by Claude COULOMBE - PhD candidate - TÉLUQ / UQAM - Montréal
#
# ### Introduction - A Minimum Viable Experiment (MVE)
#
# Get started with reinforcement learning in less than 200 lines of code with Keras (Theano or Tensorflow, it’s your choice).
#
# <img src="CatchVideogame_RL_Qlearning_Original.gif" width=200>
#
# So you are a (Supervised) Machine Learning practitioner that was also sold the hype of making your labels weaker and to the possibility of getting neural networks to play your favorite games. You want to do Reinforcement Learning (RL), but you find it hard to read all those full featured libraries just to get a feeling of what is actually going on.
#
# Here we’ve got your back: we took the game engine complexities out of the way and show a minimal Reinforcement Learning example with less than 200 lines of code. And yes, the example does use Keras, your favorite deep learning library! That's a Minimum Viable Experiment (MVE).
#
# Before I give you a link to the code make sure you read Nervana’s blog post <a href="http://www.nervanasys.com/demystifying-deep-reinforcement-learning/">Demystifying Deep Reinforcement Learning</a>. There you will learn about Q-learning, which is one of the many ways of doing RL. Also, at this point you already know that neural nets love mini-batches and there you will see what Experience Replay is and how to use it to get you them batches - even in problems where an agent only sees one sample of the environment state at a time.
#
# ### Code walkthrough
#
# So here is the <a href="https://gist.github.com/EderSantana/c7222daa328f0e885093">link to our code</a>. In that code Keras plays the catch videogame, where it should catch a single pixel “fruit” using a three pixel “basket”. The fruit falls one pixel per step and the Keras network gets a reward of +1 if it catches the fruit and -1 otherwise (code below).
# ``` Python
# def _get_reward(self):
#     fruit_row, fruit_col, basket = self.state[0]
#     if fruit_row == self.grid_size-1:
#         if abs(fruit_col - basket) <= 1:
#             return 1
#         else:
#             return -1
#     else:
#         return 0
# ```
# The networks see the entire 10x10 pixels grid as input (code below)
# ``` Python
# def _draw_state(self):
#     im_size = (self.grid_size,)*2
#     state = self.state[0]
#     canvas = np.zeros(im_size)
#     canvas[state[0], state[1]] = 1  # draw fruit
#     canvas[-1, state[2]-1:state[2] + 2] = 1  # draw basket
#     return canvas
# ```
# and outputs three values, each value corresponds to an action (move left, stay, move right).
# ``` Python
# model.add(Dense(num_actions))
# ```
# Since these values represent the expected accumulated future reward, we just go greedy and pick the action corresponding to the largest value (code below):
# ``` Python
#     q = model.predict(input_tm1)
#     action = np.argmax(q[0])
# ```
#
# One thing to note though, is that this network is not quite like you in exotic restaurants, it doesn’t take the very same action exploiting what it already knows at every time, once in a while we force system to take a random action (code below). This would be the equivalent of you learning that life is more than just `Penang Curry` with `fried Tempeh` by trial and error.
# ``` Python
# if np.random.rand() <= epsilon:
#     action = np.random.randint(0, num_actions, size=1)
# ```
#
# In the link you will also find scripts that plays the game with no random actions and generates the pictures for the animation above.
#
# Enjoy!
#
# ### FAQ
#
# #### 1) How does this Q-learning thing even work?
#
# C’mon read the blog post I just mentioned above… Anyway, think like this: the fruit is almost hitting the ground and your model is just one pixel away from a “catching” position. The model will face similar cases many many times. If it decides to stay or move left, it will be punished (imagine it smelling a bunch of rotten fruits in the ground because it was lazy). Thus, it learns to assign a small Q-value (sounds much better than just “output of neural net”, han?) to those two actions whenever it sees that picture as input. But, since catching the fruit also gives a juicy +1 reward, the model will learn to assign a larger Q-value to the “move right” action in that case. This is what minimizing the reward - Q-value error does (code below).
# ``` Python
#     # There should be no target values for actions not taken.
#     # Thou shalt not correct actions not taken #deep
#     targets[i] = model.predict(state_t)[0]
#     Q_sa = np.max(model.predict(state_tp1)[0])
#     if game_over:  # if game_over is True
#         targets[i, action_t] = reward_t
#     else:
#         # reward_t + gamma * max_a' Q(s', a')
#         targets[i, action_t] = reward_t + self.discount * Q_sa
# ```
#
# One step before that, there will be no reward in the next step.
#
# I liked how the previous phrase sounded, so I decided to give it its own paragraph. But, although in that case there is no juicy reward right after, the model can be trained using the maximum Q-value of the future state in the next step. Think about it. If you’re in the kitchen you know that you can just open the fridge to get food. But now you’re in your bedroom writing bad jokes and feel hungry. But you have this vague memory that going to the kitchen could help with that. You just go to the kitchen and there you figure how to help yourself. You have to learn all that by living the game. I know, being Markovian is hard! But then the rest is just propagating these reward expectations further and further into the past, assigning high values for good choices and low values for bad choices (don’t forget that sometimes you hit those random choices in college so you learn the parts of life they don’t talk about in school). For everything else, if you believe in Stochastic Gradient Descent then it is easy to see this actually making sense… I hope…
#
# #### 2) How different is that from AlphaGo?
#
# Not much… But instead of learning Q-values, AlphaGo thought it was smarter to use REINFORCE and learn to output actions probabilities directly. After that, she played several games against herself, so many that it could later learn the probability of winning from each position. Using all that information, during play time she uses a search technique to look for possible actions that would take her to positions with higher probability of winning. But she told me to mention here that she doesn’t search as many possibilities in the future as her older cousin DeepBlue did. She also said that she can play pretty well using just one GPU, the other 99 were running high resolution Netflix series so she can catch up with human culture.
#
# That being said, you should be able to modify this script in 2 or 3 days to get a reimplementation or AlphaGo and Skynet should be 4 weeks away?
#
# JK
#
# #### 3) Your code sucks why don’t you write something better?
#
# <a href="https://github.com/EderSantana/X/blob/master/examples/catcher.py">I’m trying…</a>
#
# #### 4) Did you learn that by yourself?
#
# The bad parts, yes. The good things were taught to me by my friends Evan Kriminger and Matthew Emigh.
#
# ### <a href="http://edersantana.github.io/">« Full blog<a>

# %% [markdown]
# ### Train...

# %%
import json
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import sgd

class Catch(object):

    def __init__(self, grid_size=10):
        self.grid_size = grid_size
        self.reset()

    def _update_state(self, action):
        """
        Input: action and states
        Ouput: new states and reward
        """
        state = self.state
        if action == 0:  # left
            action = -1
        elif action == 1:  # stay
            action = 0
        else:
            action = 1  # right
        f0, f1, basket = state[0]
        new_basket = min(max(1, basket + action), self.grid_size-1)
        f0 += 1
        out = np.asarray([f0, f1, new_basket])
        out = out[np.newaxis]

        assert len(out.shape) == 2
        self.state = out

    def _draw_state(self):
        im_size = (self.grid_size,)*2
        state = self.state[0]
        canvas = np.zeros(im_size)
        canvas[state[0], state[1]] = 1  # draw fruit
        canvas[-1, state[2]-1:state[2] + 2] = 1  # draw basket
        return canvas

    def _get_reward(self):
        fruit_row, fruit_col, basket = self.state[0]
        if fruit_row == self.grid_size-1:
            if abs(fruit_col - basket) <= 1:
                return 1
            else:
                return -1
        else:
            return 0

    def _is_over(self):
        if self.state[0, 0] == self.grid_size-1:
            return True
        else:
            return False

    def observe(self):
        canvas = self._draw_state()
        return canvas.reshape((1, -1))

    def act(self, action):
        self._update_state(action)
        reward = self._get_reward()
        game_over = self._is_over()
        return self.observe(), reward, game_over

    def reset(self):
        n = np.random.randint(0, self.grid_size-1, size=1)
        m = np.random.randint(1, self.grid_size-2, size=1)
        self.state = np.asarray([0, n, m])[np.newaxis]

class ExperienceReplay(object):
    def __init__(self, max_memory=100, discount=.9):
        self.max_memory = max_memory
        self.memory = list()
        self.discount = discount

    def remember(self, states, game_over):
        # memory[i] = [[state_t, action_t, reward_t, state_t+1], game_over?]
        self.memory.append([states, game_over])
        if len(self.memory) > self.max_memory:
            del self.memory[0]

    def get_batch(self, model, batch_size=10):
        len_memory = len(self.memory)
        num_actions = model.output_shape[-1]
        env_dim = self.memory[0][0][0].shape[1]
        inputs = np.zeros((min(len_memory, batch_size), env_dim))
        targets = np.zeros((inputs.shape[0], num_actions))
        for i, idx in enumerate(np.random.randint(0, len_memory,
                                                  size=inputs.shape[0])):
            state_t, action_t, reward_t, state_tp1 = self.memory[idx][0]
            game_over = self.memory[idx][1]

            inputs[i:i+1] = state_t
            # There should be no target values for actions not taken.
            # Thou shalt not correct actions not taken #deep
            targets[i] = model.predict(state_t)[0]
            Q_sa = np.max(model.predict(state_tp1)[0])
            if game_over:  # if game_over is True
                targets[i, action_t] = reward_t
            else:
                # reward_t + gamma * max_a' Q(s', a')
                targets[i, action_t] = reward_t + self.discount * Q_sa
        return inputs, targets

if __name__ == "__main__":
    # parameters
    epsilon = .1  # exploration
    num_actions = 3  # [move_left, stay, move_right]
    epoch = 1000
    max_memory = 500
    hidden_size = 100
    batch_size = 50
    grid_size = 10

    model = Sequential()
    model.add(Dense(hidden_size, input_shape=(grid_size**2,), activation='relu'))
    model.add(Dense(hidden_size, activation='relu'))
    model.add(Dense(num_actions))
    model.compile(sgd(lr=.2), "mse")

    # If you want to continue training from a previous model, just uncomment the line bellow
    # model.load_weights("model.h5")

    # Define environment/game
    env = Catch(grid_size)

    # Initialize experience replay object
    exp_replay = ExperienceReplay(max_memory=max_memory)

    # Train
    win_cnt = 0
    for e in range(epoch):
        loss = 0.
        env.reset()
        game_over = False
        # get initial input
        input_t = env.observe()

        while not game_over:
            input_tm1 = input_t
            # get next action
            if np.random.rand() <= epsilon:
                action = np.random.randint(0, num_actions, size=1)
            else:
                q = model.predict(input_tm1)
                action = np.argmax(q[0])

            # apply action, get rewards and new state
            input_t, reward, game_over = env.act(action)
            if reward == 1:
                win_cnt += 1

            # store experience
            exp_replay.remember([input_tm1, action, reward, input_t], game_over)

            # adapt model
            inputs, targets = exp_replay.get_batch(model, batch_size=batch_size)

#             loss += model.train_on_batch(inputs, targets)[0]
            loss += model.train_on_batch(inputs, targets)
        print("Epoch {:03d}/999 | Loss {:.4f} | Win count {}".format(e, loss, win_cnt))

    # Save trained model weights and architecture, this will be used by the visualization code
    model.save_weights("model.h5", overwrite=True)
    with open("model.json", "w") as outfile:
        json.dump(model.to_json(), outfile)
        
print("Training completed!")
# Out:
# Epoch 000/999 | Loss 0.0660 | Win count 1
# Epoch 001/999 | Loss 0.1317 | Win count 1
# Epoch 002/999 | Loss 0.1505 | Win count 1
# Epoch 003/999 | Loss 0.1930 | Win count 1
# Epoch 004/999 | Loss 0.2347 | Win count 1
# Epoch 005/999 | Loss 0.1623 | Win count 1
# Epoch 006/999 | Loss 0.1986 | Win count 1
# Epoch 007/999 | Loss 0.1931 | Win count 2
# Epoch 008/999 | Loss 0.2256 | Win count 2
# Epoch 009/999 | Loss 0.2228 | Win count 2
# Epoch 010/999 | Loss 0.2068 | Win count 2
# Epoch 011/999 | Loss 0.2234 | Win count 2
# Epoch 012/999 | Loss 0.1819 | Win count 2
# Epoch 013/999 | Loss 0.1722 | Win count 2
# Epoch 014/999 | Loss 0.1817 | Win count 2
# Epoch 015/999 | Loss 0.1620 | Win count 3
# Epoch 016/999 | Loss 0.1731 | Win count 3
# Epoch 017/999 | Loss 0.1244 | Win count 4
# Epoch 018/999 | Loss 0.1605 | Win count 4
# Epoch 019/999 | Loss 0.1705 | Win count 4
# Epoch 020/999 | Loss 0.2126 | Win count 5
# Epoch 021/999 | Loss 0.1582 | Win count 5
# Epoch 022/999 | Loss 0.1830 | Win count 5
# Epoch 023/999 | Loss 0.1779 | Win count 5
# Epoch 024/999 | Loss 0.1769 | Win count 6
# Epoch 025/999 | Loss 0.1580 | Win count 6
# Epoch 026/999 | Loss 0.2257 | Win count 6
# Epoch 027/999 | Loss 0.1903 | Win count 6
# Epoch 028/999 | Loss 0.1255 | Win count 6
# Epoch 029/999 | Loss 0.1895 | Win count 6
# Epoch 030/999 | Loss 0.1341 | Win count 6
# Epoch 031/999 | Loss 0.1863 | Win count 6
# Epoch 032/999 | Loss 0.1689 | Win count 7
# Epoch 033/999 | Loss 0.1827 | Win count 7
# Epoch 034/999 | Loss 0.1831 | Win count 7
# Epoch 035/999 | Loss 0.1684 | Win count 7
# Epoch 036/999 | Loss 0.1444 | Win count 7
# Epoch 037/999 | Loss 0.1622 | Win count 7
# Epoch 038/999 | Loss 0.1253 | Win count 8
# Epoch 039/999 | Loss 0.1537 | Win count 8
# Epoch 040/999 | Loss 0.1738 | Win count 8
# Epoch 041/999 | Loss 0.1810 | Win count 8
# Epoch 042/999 | Loss 0.1423 | Win count 8
# Epoch 043/999 | Loss 0.1474 | Win count 8
# Epoch 044/999 | Loss 0.1689 | Win count 8
# Epoch 045/999 | Loss 0.1548 | Win count 9
# Epoch 046/999 | Loss 0.1711 | Win count 9
# Epoch 047/999 | Loss 0.1880 | Win count 9
# Epoch 048/999 | Loss 0.1349 | Win count 10
# Epoch 049/999 | Loss 0.1134 | Win count 10
# Epoch 050/999 | Loss 0.1613 | Win count 10
# Epoch 051/999 | Loss 0.1628 | Win count 10
# Epoch 052/999 | Loss 0.1482 | Win count 10
# Epoch 053/999 | Loss 0.1677 | Win count 10
# Epoch 054/999 | Loss 0.1781 | Win count 10
# Epoch 055/999 | Loss 0.1101 | Win count 10
# Epoch 056/999 | Loss 0.1483 | Win count 10
# Epoch 057/999 | Loss 0.1026 | Win count 11
# Epoch 058/999 | Loss 0.1501 | Win count 11
# Epoch 059/999 | Loss 0.1196 | Win count 11
# Epoch 060/999 | Loss 0.1439 | Win count 11
# Epoch 061/999 | Loss 0.1468 | Win count 12
# Epoch 062/999 | Loss 0.1305 | Win count 12
# Epoch 063/999 | Loss 0.1967 | Win count 12
# Epoch 064/999 | Loss 0.1189 | Win count 12
# Epoch 065/999 | Loss 0.1363 | Win count 12
# Epoch 066/999 | Loss 0.1282 | Win count 12
# Epoch 067/999 | Loss 0.1594 | Win count 12
# Epoch 068/999 | Loss 0.1696 | Win count 12
# Epoch 069/999 | Loss 0.1599 | Win count 13
# Epoch 070/999 | Loss 0.1216 | Win count 14
# Epoch 071/999 | Loss 0.1166 | Win count 14
# Epoch 072/999 | Loss 0.1862 | Win count 14
# Epoch 073/999 | Loss 0.1276 | Win count 15
# Epoch 074/999 | Loss 0.1555 | Win count 15
# Epoch 075/999 | Loss 0.1370 | Win count 15
# Epoch 076/999 | Loss 0.1131 | Win count 15
# Epoch 077/999 | Loss 0.1318 | Win count 15
# Epoch 078/999 | Loss 0.1268 | Win count 16
# Epoch 079/999 | Loss 0.1127 | Win count 17
# Epoch 080/999 | Loss 0.1222 | Win count 17
# Epoch 081/999 | Loss 0.1382 | Win count 17
# Epoch 082/999 | Loss 0.1265 | Win count 17
# Epoch 083/999 | Loss 0.1617 | Win count 17
# Epoch 084/999 | Loss 0.1165 | Win count 17
# Epoch 085/999 | Loss 0.1360 | Win count 18
# Epoch 086/999 | Loss 0.1264 | Win count 19
# Epoch 087/999 | Loss 0.1179 | Win count 19
# Epoch 088/999 | Loss 0.1055 | Win count 19
# Epoch 089/999 | Loss 0.1588 | Win count 19
# Epoch 090/999 | Loss 0.0987 | Win count 19
# Epoch 091/999 | Loss 0.1352 | Win count 19
# Epoch 092/999 | Loss 0.1441 | Win count 20
# Epoch 093/999 | Loss 0.1135 | Win count 21
# Epoch 094/999 | Loss 0.0985 | Win count 21
# Epoch 095/999 | Loss 0.1402 | Win count 21
# Epoch 096/999 | Loss 0.1450 | Win count 21
# Epoch 097/999 | Loss 0.1271 | Win count 22
# Epoch 098/999 | Loss 0.1139 | Win count 22
# Epoch 099/999 | Loss 0.1255 | Win count 22
# Epoch 100/999 | Loss 0.1286 | Win count 23
# Epoch 101/999 | Loss 0.1261 | Win count 23
# Epoch 102/999 | Loss 0.0969 | Win count 24
# Epoch 103/999 | Loss 0.0850 | Win count 24
# Epoch 104/999 | Loss 0.1328 | Win count 25
# Epoch 105/999 | Loss 0.0936 | Win count 26
# Epoch 106/999 | Loss 0.1289 | Win count 26
# Epoch 107/999 | Loss 0.1196 | Win count 26
# Epoch 108/999 | Loss 0.1071 | Win count 27
# Epoch 109/999 | Loss 0.0984 | Win count 27
# Epoch 110/999 | Loss 0.1087 | Win count 27
# Epoch 111/999 | Loss 0.1159 | Win count 28
# Epoch 112/999 | Loss 0.1067 | Win count 29
# Epoch 113/999 | Loss 0.0967 | Win count 29
# Epoch 114/999 | Loss 0.1153 | Win count 30
# Epoch 115/999 | Loss 0.1241 | Win count 31
# Epoch 116/999 | Loss 0.0907 | Win count 31
# Epoch 117/999 | Loss 0.1233 | Win count 31
# Epoch 118/999 | Loss 0.1124 | Win count 32
# Epoch 119/999 | Loss 0.1275 | Win count 33
# Epoch 120/999 | Loss 0.1068 | Win count 33
# Epoch 121/999 | Loss 0.1123 | Win count 33
# Epoch 122/999 | Loss 0.1065 | Win count 34
# Epoch 123/999 | Loss 0.1415 | Win count 35
# Epoch 124/999 | Loss 0.1047 | Win count 36
# Epoch 125/999 | Loss 0.1000 | Win count 36
# Epoch 126/999 | Loss 0.1005 | Win count 37
# Epoch 127/999 | Loss 0.1037 | Win count 38
# Epoch 128/999 | Loss 0.1098 | Win count 38
# Epoch 129/999 | Loss 0.1013 | Win count 38
# Epoch 130/999 | Loss 0.0850 | Win count 38
# Epoch 131/999 | Loss 0.0851 | Win count 39
# Epoch 132/999 | Loss 0.1225 | Win count 39
# Epoch 133/999 | Loss 0.0963 | Win count 39
# Epoch 134/999 | Loss 0.0926 | Win count 40
# Epoch 135/999 | Loss 0.1085 | Win count 40
# Epoch 136/999 | Loss 0.0987 | Win count 40
# Epoch 137/999 | Loss 0.1118 | Win count 40
# Epoch 138/999 | Loss 0.1183 | Win count 41
# Epoch 139/999 | Loss 0.1250 | Win count 41
# Epoch 140/999 | Loss 0.1184 | Win count 41
# Epoch 141/999 | Loss 0.1075 | Win count 41
# Epoch 142/999 | Loss 0.1008 | Win count 42
# Epoch 143/999 | Loss 0.1407 | Win count 43
# Epoch 144/999 | Loss 0.0991 | Win count 43
# Epoch 145/999 | Loss 0.0977 | Win count 43
# Epoch 146/999 | Loss 0.1040 | Win count 44
# Epoch 147/999 | Loss 0.1461 | Win count 45
# Epoch 148/999 | Loss 0.1021 | Win count 46
# Epoch 149/999 | Loss 0.1067 | Win count 46
# Epoch 150/999 | Loss 0.0723 | Win count 47
# Epoch 151/999 | Loss 0.1310 | Win count 48
# Epoch 152/999 | Loss 0.1307 | Win count 49
# Epoch 153/999 | Loss 0.0935 | Win count 49
# Epoch 154/999 | Loss 0.1322 | Win count 50
# Epoch 155/999 | Loss 0.1025 | Win count 50
# Epoch 156/999 | Loss 0.1463 | Win count 51
# Epoch 157/999 | Loss 0.1074 | Win count 52
# Epoch 158/999 | Loss 0.1355 | Win count 53
# Epoch 159/999 | Loss 0.0972 | Win count 54
# Epoch 160/999 | Loss 0.1137 | Win count 55
# Epoch 161/999 | Loss 0.1490 | Win count 56
# Epoch 162/999 | Loss 0.1044 | Win count 57
# Epoch 163/999 | Loss 0.0978 | Win count 58
# Epoch 164/999 | Loss 0.1214 | Win count 58
# Epoch 165/999 | Loss 0.1203 | Win count 59
# Epoch 166/999 | Loss 0.1078 | Win count 60
# Epoch 167/999 | Loss 0.1016 | Win count 60
# Epoch 168/999 | Loss 0.1146 | Win count 60
# Epoch 169/999 | Loss 0.1145 | Win count 61
# Epoch 170/999 | Loss 0.1278 | Win count 61
# Epoch 171/999 | Loss 0.0895 | Win count 61
# Epoch 172/999 | Loss 0.1504 | Win count 61
# Epoch 173/999 | Loss 0.1062 | Win count 62
# Epoch 174/999 | Loss 0.1414 | Win count 62
# Epoch 175/999 | Loss 0.1386 | Win count 63
# Epoch 176/999 | Loss 0.1167 | Win count 64
# Epoch 177/999 | Loss 0.0900 | Win count 65
# Epoch 178/999 | Loss 0.1083 | Win count 65
# Epoch 179/999 | Loss 0.1217 | Win count 66
# Epoch 180/999 | Loss 0.1187 | Win count 66
# Epoch 181/999 | Loss 0.1030 | Win count 66
# Epoch 182/999 | Loss 0.1027 | Win count 67
# Epoch 183/999 | Loss 0.1337 | Win count 68
# Epoch 184/999 | Loss 0.1478 | Win count 68
# Epoch 185/999 | Loss 0.1413 | Win count 69
# Epoch 186/999 | Loss 0.1062 | Win count 69
# Epoch 187/999 | Loss 0.1282 | Win count 69
# Epoch 188/999 | Loss 0.1049 | Win count 70
# Epoch 189/999 | Loss 0.1649 | Win count 71
# Epoch 190/999 | Loss 0.1125 | Win count 71
# Epoch 191/999 | Loss 0.1051 | Win count 71
# Epoch 192/999 | Loss 0.1597 | Win count 71
# Epoch 193/999 | Loss 0.1925 | Win count 72
# Epoch 194/999 | Loss 0.1481 | Win count 72
# Epoch 195/999 | Loss 0.1314 | Win count 73
# Epoch 196/999 | Loss 0.1338 | Win count 74
# Epoch 197/999 | Loss 0.1409 | Win count 75
# Epoch 198/999 | Loss 0.1232 | Win count 75
# Epoch 199/999 | Loss 0.1378 | Win count 75
# Epoch 200/999 | Loss 0.1251 | Win count 76
# Epoch 201/999 | Loss 0.1434 | Win count 76
# Epoch 202/999 | Loss 0.1402 | Win count 77
# Epoch 203/999 | Loss 0.1335 | Win count 78
# Epoch 204/999 | Loss 0.1061 | Win count 78
# Epoch 205/999 | Loss 0.1132 | Win count 79
# Epoch 206/999 | Loss 0.0950 | Win count 79
# Epoch 207/999 | Loss 0.1058 | Win count 79
# Epoch 208/999 | Loss 0.1043 | Win count 80
# Epoch 209/999 | Loss 0.1049 | Win count 80
# Epoch 210/999 | Loss 0.1035 | Win count 80
# Epoch 211/999 | Loss 0.0935 | Win count 81
# Epoch 212/999 | Loss 0.0881 | Win count 81
# Epoch 213/999 | Loss 0.0887 | Win count 82
# Epoch 214/999 | Loss 0.0833 | Win count 83
# Epoch 215/999 | Loss 0.0983 | Win count 83
# Epoch 216/999 | Loss 0.1270 | Win count 84
# Epoch 217/999 | Loss 0.1037 | Win count 85
# Epoch 218/999 | Loss 0.0877 | Win count 85
# Epoch 219/999 | Loss 0.1051 | Win count 86
# Epoch 220/999 | Loss 0.0835 | Win count 87
# Epoch 221/999 | Loss 0.0863 | Win count 88
# Epoch 222/999 | Loss 0.1105 | Win count 89
# Epoch 223/999 | Loss 0.0689 | Win count 89
# Epoch 224/999 | Loss 0.0878 | Win count 90
# Epoch 225/999 | Loss 0.0837 | Win count 90
# Epoch 226/999 | Loss 0.0958 | Win count 90
# Epoch 227/999 | Loss 0.0877 | Win count 91
# Epoch 228/999 | Loss 0.1186 | Win count 91
# Epoch 229/999 | Loss 0.1047 | Win count 92
# Epoch 230/999 | Loss 0.1100 | Win count 93
# Epoch 231/999 | Loss 0.1076 | Win count 93
# Epoch 232/999 | Loss 0.0752 | Win count 94
# Epoch 233/999 | Loss 0.0958 | Win count 95
# Epoch 234/999 | Loss 0.1022 | Win count 96
# Epoch 235/999 | Loss 0.0939 | Win count 97
# Epoch 236/999 | Loss 0.0845 | Win count 98
# Epoch 237/999 | Loss 0.0697 | Win count 99
# Epoch 238/999 | Loss 0.1066 | Win count 100
# Epoch 239/999 | Loss 0.0805 | Win count 101
# Epoch 240/999 | Loss 0.0918 | Win count 102
# Epoch 241/999 | Loss 0.0636 | Win count 103
# Epoch 242/999 | Loss 0.1017 | Win count 104
# Epoch 243/999 | Loss 0.0778 | Win count 105
# Epoch 244/999 | Loss 0.0689 | Win count 105
# Epoch 245/999 | Loss 0.0795 | Win count 106
# Epoch 246/999 | Loss 0.0755 | Win count 107
# Epoch 247/999 | Loss 0.0594 | Win count 108
# Epoch 248/999 | Loss 0.0674 | Win count 109
# Epoch 249/999 | Loss 0.0747 | Win count 110
# Epoch 250/999 | Loss 0.0628 | Win count 110
# Epoch 251/999 | Loss 0.0659 | Win count 111
# Epoch 252/999 | Loss 0.0764 | Win count 112
# Epoch 253/999 | Loss 0.0567 | Win count 113
# Epoch 254/999 | Loss 0.0809 | Win count 113
# Epoch 255/999 | Loss 0.0735 | Win count 113
# Epoch 256/999 | Loss 0.0743 | Win count 113
# Epoch 257/999 | Loss 0.0776 | Win count 114
# Epoch 258/999 | Loss 0.0658 | Win count 115
# Epoch 259/999 | Loss 0.0568 | Win count 116
# Epoch 260/999 | Loss 0.0806 | Win count 116
# Epoch 261/999 | Loss 0.0688 | Win count 117
# Epoch 262/999 | Loss 0.0822 | Win count 117
# Epoch 263/999 | Loss 0.0691 | Win count 118
# Epoch 264/999 | Loss 0.0616 | Win count 118
# Epoch 265/999 | Loss 0.0670 | Win count 118
# Epoch 266/999 | Loss 0.0766 | Win count 118
# Epoch 267/999 | Loss 0.0606 | Win count 118
# Epoch 268/999 | Loss 0.0530 | Win count 118
# Epoch 269/999 | Loss 0.0610 | Win count 118
# Epoch 270/999 | Loss 0.0689 | Win count 118
# Epoch 271/999 | Loss 0.0827 | Win count 119
# Epoch 272/999 | Loss 0.0609 | Win count 120
# Epoch 273/999 | Loss 0.0592 | Win count 121
# Epoch 274/999 | Loss 0.0682 | Win count 122
# Epoch 275/999 | Loss 0.0499 | Win count 123
# Epoch 276/999 | Loss 0.0896 | Win count 124
# Epoch 277/999 | Loss 0.0630 | Win count 125
# Epoch 278/999 | Loss 0.0520 | Win count 125
# Epoch 279/999 | Loss 0.0598 | Win count 126
# Epoch 280/999 | Loss 0.0638 | Win count 127
# Epoch 281/999 | Loss 0.0744 | Win count 127
# Epoch 282/999 | Loss 0.0687 | Win count 127
# Epoch 283/999 | Loss 0.0761 | Win count 127
# Epoch 284/999 | Loss 0.0770 | Win count 128
# Epoch 285/999 | Loss 0.0606 | Win count 129
# Epoch 286/999 | Loss 0.0939 | Win count 130
# Epoch 287/999 | Loss 0.0508 | Win count 131
# Epoch 288/999 | Loss 0.0778 | Win count 132
# Epoch 289/999 | Loss 0.0773 | Win count 133
# Epoch 290/999 | Loss 0.0766 | Win count 134
# Epoch 291/999 | Loss 0.0820 | Win count 134
# Epoch 292/999 | Loss 0.0815 | Win count 134
# Epoch 293/999 | Loss 0.0720 | Win count 135
# Epoch 294/999 | Loss 0.0620 | Win count 136
# Epoch 295/999 | Loss 0.0632 | Win count 136
# Epoch 296/999 | Loss 0.0857 | Win count 137
# Epoch 297/999 | Loss 0.1187 | Win count 137
# Epoch 298/999 | Loss 0.0818 | Win count 137
# Epoch 299/999 | Loss 0.0782 | Win count 138
# Epoch 300/999 | Loss 0.0968 | Win count 139
# Epoch 301/999 | Loss 0.0759 | Win count 139
# Epoch 302/999 | Loss 0.0596 | Win count 139
# Epoch 303/999 | Loss 0.0897 | Win count 140
# Epoch 304/999 | Loss 0.0577 | Win count 141
# Epoch 305/999 | Loss 0.0534 | Win count 142
# Epoch 306/999 | Loss 0.0675 | Win count 143
# Epoch 307/999 | Loss 0.0679 | Win count 144
# Epoch 308/999 | Loss 0.0726 | Win count 145
# Epoch 309/999 | Loss 0.0566 | Win count 146
# Epoch 310/999 | Loss 0.0565 | Win count 147
# Epoch 311/999 | Loss 0.0634 | Win count 148
# Epoch 312/999 | Loss 0.0735 | Win count 149
# Epoch 313/999 | Loss 0.0764 | Win count 150
# Epoch 314/999 | Loss 0.0526 | Win count 151
# Epoch 315/999 | Loss 0.0779 | Win count 151
# Epoch 316/999 | Loss 0.0845 | Win count 152
# Epoch 317/999 | Loss 0.1097 | Win count 152
# Epoch 318/999 | Loss 0.0699 | Win count 152
# Epoch 319/999 | Loss 0.0697 | Win count 153
# Epoch 320/999 | Loss 0.0796 | Win count 153
# Epoch 321/999 | Loss 0.1001 | Win count 154
# Epoch 322/999 | Loss 0.0862 | Win count 155
# Epoch 323/999 | Loss 0.0757 | Win count 156
# Epoch 324/999 | Loss 0.0617 | Win count 156
# Epoch 325/999 | Loss 0.0631 | Win count 157
# Epoch 326/999 | Loss 0.0629 | Win count 157
# Epoch 327/999 | Loss 0.0484 | Win count 158
# Epoch 328/999 | Loss 0.0676 | Win count 159
# Epoch 329/999 | Loss 0.0503 | Win count 159
# Epoch 330/999 | Loss 0.0404 | Win count 159
# Epoch 331/999 | Loss 0.0512 | Win count 160
# Epoch 332/999 | Loss 0.0866 | Win count 160
# Epoch 333/999 | Loss 0.0999 | Win count 160
# Epoch 334/999 | Loss 0.0572 | Win count 161
# Epoch 335/999 | Loss 0.1201 | Win count 162
# Epoch 336/999 | Loss 0.1131 | Win count 162
# Epoch 337/999 | Loss 0.0678 | Win count 163
# Epoch 338/999 | Loss 0.0601 | Win count 163
# Epoch 339/999 | Loss 0.0619 | Win count 164
# Epoch 340/999 | Loss 0.0528 | Win count 165
# Epoch 341/999 | Loss 0.1171 | Win count 165
# Epoch 342/999 | Loss 0.0684 | Win count 166
# Epoch 343/999 | Loss 0.0460 | Win count 166
# Epoch 344/999 | Loss 0.0660 | Win count 167
# Epoch 345/999 | Loss 0.0666 | Win count 167
# Epoch 346/999 | Loss 0.0659 | Win count 168
# Epoch 347/999 | Loss 0.0782 | Win count 168
# Epoch 348/999 | Loss 0.1186 | Win count 169
# Epoch 349/999 | Loss 0.0675 | Win count 170
# Epoch 350/999 | Loss 0.1287 | Win count 171
# Epoch 351/999 | Loss 0.0643 | Win count 172
# Epoch 352/999 | Loss 0.0572 | Win count 172
# Epoch 353/999 | Loss 0.1060 | Win count 172
# Epoch 354/999 | Loss 0.0675 | Win count 173
# Epoch 355/999 | Loss 0.0875 | Win count 174
# Epoch 356/999 | Loss 0.0830 | Win count 175
# Epoch 357/999 | Loss 0.0470 | Win count 176
# Epoch 358/999 | Loss 0.0732 | Win count 177
# Epoch 359/999 | Loss 0.0790 | Win count 177
# Epoch 360/999 | Loss 0.0855 | Win count 178
# Epoch 361/999 | Loss 0.1418 | Win count 178
# Epoch 362/999 | Loss 0.1115 | Win count 178
# Epoch 363/999 | Loss 0.1236 | Win count 178
# Epoch 364/999 | Loss 0.1178 | Win count 179
# Epoch 365/999 | Loss 0.0804 | Win count 180
# Epoch 366/999 | Loss 0.1052 | Win count 180
# Epoch 367/999 | Loss 0.1101 | Win count 181
# Epoch 368/999 | Loss 0.0849 | Win count 181
# Epoch 369/999 | Loss 0.0581 | Win count 181
# Epoch 370/999 | Loss 0.0838 | Win count 182
# Epoch 371/999 | Loss 0.0593 | Win count 183
# Epoch 372/999 | Loss 0.0863 | Win count 183
# Epoch 373/999 | Loss 0.0745 | Win count 184
# Epoch 374/999 | Loss 0.0817 | Win count 185
# Epoch 375/999 | Loss 0.0745 | Win count 185
# Epoch 376/999 | Loss 0.0991 | Win count 186
# Epoch 377/999 | Loss 0.0527 | Win count 187
# Epoch 378/999 | Loss 0.0526 | Win count 188
# Epoch 379/999 | Loss 0.0746 | Win count 189
# Epoch 380/999 | Loss 0.0816 | Win count 190
# Epoch 381/999 | Loss 0.0865 | Win count 191
# Epoch 382/999 | Loss 0.0720 | Win count 192
# Epoch 383/999 | Loss 0.0622 | Win count 193
# Epoch 384/999 | Loss 0.0681 | Win count 194
# Epoch 385/999 | Loss 0.0546 | Win count 195
# Epoch 386/999 | Loss 0.0557 | Win count 195
# Epoch 387/999 | Loss 0.0613 | Win count 196
# Epoch 388/999 | Loss 0.0603 | Win count 197
# Epoch 389/999 | Loss 0.0819 | Win count 197
# Epoch 390/999 | Loss 0.0580 | Win count 197
# Epoch 391/999 | Loss 0.0558 | Win count 198
# Epoch 392/999 | Loss 0.0643 | Win count 199
# Epoch 393/999 | Loss 0.0569 | Win count 200
# Epoch 394/999 | Loss 0.0580 | Win count 201
# Epoch 395/999 | Loss 0.0551 | Win count 202
# Epoch 396/999 | Loss 0.0414 | Win count 202
# Epoch 397/999 | Loss 0.0433 | Win count 203
# Epoch 398/999 | Loss 0.0429 | Win count 203
# Epoch 399/999 | Loss 0.0510 | Win count 204
# Epoch 400/999 | Loss 0.0579 | Win count 205
# Epoch 401/999 | Loss 0.0665 | Win count 205
# Epoch 402/999 | Loss 0.0459 | Win count 206
# Epoch 403/999 | Loss 0.0415 | Win count 206
# Epoch 404/999 | Loss 0.0464 | Win count 207
# Epoch 405/999 | Loss 0.0300 | Win count 208
# Epoch 406/999 | Loss 0.0396 | Win count 209
# Epoch 407/999 | Loss 0.0473 | Win count 210
# Epoch 408/999 | Loss 0.0438 | Win count 211
# Epoch 409/999 | Loss 0.0475 | Win count 212
# Epoch 410/999 | Loss 0.0303 | Win count 213
# Epoch 411/999 | Loss 0.0533 | Win count 214
# Epoch 412/999 | Loss 0.0607 | Win count 215
# Epoch 413/999 | Loss 0.0454 | Win count 216
# Epoch 414/999 | Loss 0.0486 | Win count 217
# Epoch 415/999 | Loss 0.0406 | Win count 218
# Epoch 416/999 | Loss 0.0372 | Win count 219
# Epoch 417/999 | Loss 0.0430 | Win count 220
# Epoch 418/999 | Loss 0.0380 | Win count 221
# Epoch 419/999 | Loss 0.0293 | Win count 221
# Epoch 420/999 | Loss 0.0332 | Win count 222
# Epoch 421/999 | Loss 0.0347 | Win count 223
# Epoch 422/999 | Loss 0.0288 | Win count 224
# Epoch 423/999 | Loss 0.0257 | Win count 224
# Epoch 424/999 | Loss 0.0332 | Win count 224
# Epoch 425/999 | Loss 0.0509 | Win count 225
# Epoch 426/999 | Loss 0.0350 | Win count 226
# Epoch 427/999 | Loss 0.0463 | Win count 227
# Epoch 428/999 | Loss 0.0338 | Win count 228
# Epoch 429/999 | Loss 0.0482 | Win count 228
# Epoch 430/999 | Loss 0.0434 | Win count 229
# Epoch 431/999 | Loss 0.0391 | Win count 229
# Epoch 432/999 | Loss 0.0406 | Win count 229
# Epoch 433/999 | Loss 0.0534 | Win count 230
# Epoch 434/999 | Loss 0.0580 | Win count 231
# Epoch 435/999 | Loss 0.0307 | Win count 232
# Epoch 436/999 | Loss 0.0466 | Win count 233
# Epoch 437/999 | Loss 0.0610 | Win count 234
# Epoch 438/999 | Loss 0.0476 | Win count 235
# Epoch 439/999 | Loss 0.0522 | Win count 236
# Epoch 440/999 | Loss 0.0591 | Win count 237
# Epoch 441/999 | Loss 0.0630 | Win count 237
# Epoch 442/999 | Loss 0.0357 | Win count 238
# Epoch 443/999 | Loss 0.0441 | Win count 238
# Epoch 444/999 | Loss 0.0493 | Win count 239
# Epoch 445/999 | Loss 0.0440 | Win count 240
# Epoch 446/999 | Loss 0.0335 | Win count 241
# Epoch 447/999 | Loss 0.0354 | Win count 242
# Epoch 448/999 | Loss 0.0647 | Win count 243
# Epoch 449/999 | Loss 0.0460 | Win count 244
# Epoch 450/999 | Loss 0.0311 | Win count 245
# Epoch 451/999 | Loss 0.0538 | Win count 246
# Epoch 452/999 | Loss 0.0521 | Win count 247
# Epoch 453/999 | Loss 0.0455 | Win count 247
# Epoch 454/999 | Loss 0.0400 | Win count 248
# Epoch 455/999 | Loss 0.0511 | Win count 249
# Epoch 456/999 | Loss 0.0422 | Win count 250
# Epoch 457/999 | Loss 0.0423 | Win count 251
# Epoch 458/999 | Loss 0.0419 | Win count 252
# Epoch 459/999 | Loss 0.0296 | Win count 253
# Epoch 460/999 | Loss 0.0363 | Win count 254
# Epoch 461/999 | Loss 0.0330 | Win count 255
# Epoch 462/999 | Loss 0.0286 | Win count 256
# Epoch 463/999 | Loss 0.0281 | Win count 257
# Epoch 464/999 | Loss 0.0236 | Win count 258
# Epoch 465/999 | Loss 0.0275 | Win count 259
# Epoch 466/999 | Loss 0.0248 | Win count 260
# Epoch 467/999 | Loss 0.0255 | Win count 261
# Epoch 468/999 | Loss 0.0273 | Win count 262
# Epoch 469/999 | Loss 0.0271 | Win count 263
# Epoch 470/999 | Loss 0.0238 | Win count 264
# Epoch 471/999 | Loss 0.0279 | Win count 265
# Epoch 472/999 | Loss 0.0367 | Win count 266
# Epoch 473/999 | Loss 0.0199 | Win count 267
# Epoch 474/999 | Loss 0.0197 | Win count 268
# Epoch 475/999 | Loss 0.0191 | Win count 269
# Epoch 476/999 | Loss 0.0182 | Win count 270
# Epoch 477/999 | Loss 0.0196 | Win count 271
# Epoch 478/999 | Loss 0.0209 | Win count 272
# Epoch 479/999 | Loss 0.0225 | Win count 273
# Epoch 480/999 | Loss 0.0184 | Win count 274
# Epoch 481/999 | Loss 0.0164 | Win count 274
# Epoch 482/999 | Loss 0.0209 | Win count 275
# Epoch 483/999 | Loss 0.0215 | Win count 276
# Epoch 484/999 | Loss 0.0236 | Win count 277
# Epoch 485/999 | Loss 0.0203 | Win count 278
# Epoch 486/999 | Loss 0.0194 | Win count 279
# Epoch 487/999 | Loss 0.0205 | Win count 280
# Epoch 488/999 | Loss 0.0133 | Win count 281
# Epoch 489/999 | Loss 0.0210 | Win count 282
# Epoch 490/999 | Loss 0.0162 | Win count 283
# Epoch 491/999 | Loss 0.0179 | Win count 284
# Epoch 492/999 | Loss 0.0268 | Win count 285
# Epoch 493/999 | Loss 0.0213 | Win count 286
# Epoch 494/999 | Loss 0.0188 | Win count 287
# Epoch 495/999 | Loss 0.0198 | Win count 288
# Epoch 496/999 | Loss 0.0261 | Win count 289
# Epoch 497/999 | Loss 0.0159 | Win count 290
# Epoch 498/999 | Loss 0.0237 | Win count 291
# Epoch 499/999 | Loss 0.0147 | Win count 292
# Epoch 500/999 | Loss 0.0175 | Win count 293
# Epoch 501/999 | Loss 0.0146 | Win count 294
# Epoch 502/999 | Loss 0.0140 | Win count 295
# Epoch 503/999 | Loss 0.0088 | Win count 296
# Epoch 504/999 | Loss 0.0094 | Win count 297
# Epoch 505/999 | Loss 0.0093 | Win count 298
# Epoch 506/999 | Loss 0.0133 | Win count 299
# Epoch 507/999 | Loss 0.0084 | Win count 300
# Epoch 508/999 | Loss 0.0071 | Win count 301
# Epoch 509/999 | Loss 0.0066 | Win count 302
# Epoch 510/999 | Loss 0.0086 | Win count 303
# Epoch 511/999 | Loss 0.0150 | Win count 304
# Epoch 512/999 | Loss 0.0169 | Win count 305
# Epoch 513/999 | Loss 0.0109 | Win count 306
# Epoch 514/999 | Loss 0.0105 | Win count 307
# Epoch 515/999 | Loss 0.0144 | Win count 308
# Epoch 516/999 | Loss 0.0164 | Win count 309
# Epoch 517/999 | Loss 0.0121 | Win count 309
# Epoch 518/999 | Loss 0.0123 | Win count 310
# Epoch 519/999 | Loss 0.0150 | Win count 311
# Epoch 520/999 | Loss 0.0147 | Win count 312
# Epoch 521/999 | Loss 0.0173 | Win count 313
# Epoch 522/999 | Loss 0.0059 | Win count 314
# Epoch 523/999 | Loss 0.0114 | Win count 315
# Epoch 524/999 | Loss 0.0142 | Win count 315
# Epoch 525/999 | Loss 0.0068 | Win count 316
# Epoch 526/999 | Loss 0.0325 | Win count 317
# Epoch 527/999 | Loss 0.0145 | Win count 318
# Epoch 528/999 | Loss 0.0127 | Win count 319
# Epoch 529/999 | Loss 0.0158 | Win count 320
# Epoch 530/999 | Loss 0.0242 | Win count 320
# Epoch 531/999 | Loss 0.0080 | Win count 321
# Epoch 532/999 | Loss 0.0567 | Win count 322
# Epoch 533/999 | Loss 0.0369 | Win count 323
# Epoch 534/999 | Loss 0.0424 | Win count 324
# Epoch 535/999 | Loss 0.0300 | Win count 325
# Epoch 536/999 | Loss 0.0388 | Win count 326
# Epoch 537/999 | Loss 0.0308 | Win count 327
# Epoch 538/999 | Loss 0.0139 | Win count 328
# Epoch 539/999 | Loss 0.0354 | Win count 328
# Epoch 540/999 | Loss 0.0299 | Win count 329
# Epoch 541/999 | Loss 0.0412 | Win count 330
# Epoch 542/999 | Loss 0.0851 | Win count 331
# Epoch 543/999 | Loss 0.0656 | Win count 332
# Epoch 544/999 | Loss 0.0449 | Win count 333
# Epoch 545/999 | Loss 0.0249 | Win count 334
# Epoch 546/999 | Loss 0.0435 | Win count 335
# Epoch 547/999 | Loss 0.0545 | Win count 336
# Epoch 548/999 | Loss 0.0340 | Win count 337
# Epoch 549/999 | Loss 0.0204 | Win count 338
# Epoch 550/999 | Loss 0.0356 | Win count 339
# Epoch 551/999 | Loss 0.0626 | Win count 340
# Epoch 552/999 | Loss 0.0243 | Win count 341
# Epoch 553/999 | Loss 0.0318 | Win count 342
# Epoch 554/999 | Loss 0.0278 | Win count 342
# Epoch 555/999 | Loss 0.0257 | Win count 343
# Epoch 556/999 | Loss 0.0302 | Win count 344
# Epoch 557/999 | Loss 0.0213 | Win count 345
# Epoch 558/999 | Loss 0.0281 | Win count 346
# Epoch 559/999 | Loss 0.0303 | Win count 347
# Epoch 560/999 | Loss 0.0386 | Win count 348
# Epoch 561/999 | Loss 0.0220 | Win count 349
# Epoch 562/999 | Loss 0.0606 | Win count 350
# Epoch 563/999 | Loss 0.0332 | Win count 351
# Epoch 564/999 | Loss 0.0287 | Win count 352
# Epoch 565/999 | Loss 0.0346 | Win count 353
# Epoch 566/999 | Loss 0.0237 | Win count 354
# Epoch 567/999 | Loss 0.0250 | Win count 355
# Epoch 568/999 | Loss 0.0230 | Win count 356
# Epoch 569/999 | Loss 0.0178 | Win count 357
# Epoch 570/999 | Loss 0.0252 | Win count 358
# Epoch 571/999 | Loss 0.0268 | Win count 359
# Epoch 572/999 | Loss 0.0192 | Win count 360
# Epoch 573/999 | Loss 0.0201 | Win count 361
# Epoch 574/999 | Loss 0.0198 | Win count 362
# Epoch 575/999 | Loss 0.0289 | Win count 362
# Epoch 576/999 | Loss 0.0550 | Win count 363
# Epoch 577/999 | Loss 0.0429 | Win count 364
# Epoch 578/999 | Loss 0.0271 | Win count 365
# Epoch 579/999 | Loss 0.0187 | Win count 366
# Epoch 580/999 | Loss 0.0230 | Win count 367
# Epoch 581/999 | Loss 0.0196 | Win count 368
# Epoch 582/999 | Loss 0.0287 | Win count 369
# Epoch 583/999 | Loss 0.0179 | Win count 370
# Epoch 584/999 | Loss 0.0332 | Win count 371
# Epoch 585/999 | Loss 0.0219 | Win count 371
# Epoch 586/999 | Loss 0.0245 | Win count 372
# Epoch 587/999 | Loss 0.0252 | Win count 373
# Epoch 588/999 | Loss 0.0278 | Win count 374
# Epoch 589/999 | Loss 0.0148 | Win count 375
# Epoch 590/999 | Loss 0.0340 | Win count 376
# Epoch 591/999 | Loss 0.0219 | Win count 377
# Epoch 592/999 | Loss 0.0213 | Win count 378
# Epoch 593/999 | Loss 0.0167 | Win count 379
# Epoch 594/999 | Loss 0.0194 | Win count 380
# Epoch 595/999 | Loss 0.0190 | Win count 381
# Epoch 596/999 | Loss 0.0214 | Win count 382
# Epoch 597/999 | Loss 0.0092 | Win count 383
# Epoch 598/999 | Loss 0.0112 | Win count 384
# Epoch 599/999 | Loss 0.0145 | Win count 385
# Epoch 600/999 | Loss 0.0090 | Win count 386
# Epoch 601/999 | Loss 0.0118 | Win count 387
# Epoch 602/999 | Loss 0.0100 | Win count 388
# Epoch 603/999 | Loss 0.0123 | Win count 389
# Epoch 604/999 | Loss 0.0137 | Win count 390
# Epoch 605/999 | Loss 0.0106 | Win count 391
# Epoch 606/999 | Loss 0.0095 | Win count 392
# Epoch 607/999 | Loss 0.0153 | Win count 393
# Epoch 608/999 | Loss 0.0121 | Win count 393
# Epoch 609/999 | Loss 0.0229 | Win count 394
# Epoch 610/999 | Loss 0.0221 | Win count 395
# Epoch 611/999 | Loss 0.0158 | Win count 396
# Epoch 612/999 | Loss 0.0110 | Win count 397
# Epoch 613/999 | Loss 0.0209 | Win count 398
# Epoch 614/999 | Loss 0.0109 | Win count 399
# Epoch 615/999 | Loss 0.0099 | Win count 400
# Epoch 616/999 | Loss 0.0219 | Win count 401
# Epoch 617/999 | Loss 0.0139 | Win count 402
# Epoch 618/999 | Loss 0.0271 | Win count 403
# Epoch 619/999 | Loss 0.0105 | Win count 404
# Epoch 620/999 | Loss 0.0212 | Win count 404
# Epoch 621/999 | Loss 0.0242 | Win count 405
# Epoch 622/999 | Loss 0.0221 | Win count 406
# Epoch 623/999 | Loss 0.0141 | Win count 407
# Epoch 624/999 | Loss 0.0168 | Win count 408
# Epoch 625/999 | Loss 0.0088 | Win count 409
# Epoch 626/999 | Loss 0.0238 | Win count 410
# Epoch 627/999 | Loss 0.0099 | Win count 411
# Epoch 628/999 | Loss 0.0169 | Win count 412
# Epoch 629/999 | Loss 0.0136 | Win count 413
# Epoch 630/999 | Loss 0.0167 | Win count 414
# Epoch 631/999 | Loss 0.0122 | Win count 415
# Epoch 632/999 | Loss 0.0144 | Win count 416
# Epoch 633/999 | Loss 0.0174 | Win count 417
# Epoch 634/999 | Loss 0.0104 | Win count 418
# Epoch 635/999 | Loss 0.0086 | Win count 419
# Epoch 636/999 | Loss 0.0088 | Win count 420
# Epoch 637/999 | Loss 0.0099 | Win count 421
# Epoch 638/999 | Loss 0.0112 | Win count 422
# Epoch 639/999 | Loss 0.0104 | Win count 423
# Epoch 640/999 | Loss 0.0159 | Win count 424
# Epoch 641/999 | Loss 0.0131 | Win count 425
# Epoch 642/999 | Loss 0.0105 | Win count 426
# Epoch 643/999 | Loss 0.0084 | Win count 427
# Epoch 644/999 | Loss 0.0078 | Win count 428
# Epoch 645/999 | Loss 0.0064 | Win count 429
# Epoch 646/999 | Loss 0.0103 | Win count 430
# Epoch 647/999 | Loss 0.0166 | Win count 431
# Epoch 648/999 | Loss 0.0103 | Win count 432
# Epoch 649/999 | Loss 0.0098 | Win count 433
# Epoch 650/999 | Loss 0.0092 | Win count 434
# Epoch 651/999 | Loss 0.0089 | Win count 435
# Epoch 652/999 | Loss 0.0055 | Win count 436
# Epoch 653/999 | Loss 0.0116 | Win count 437
# Epoch 654/999 | Loss 0.0077 | Win count 438
# Epoch 655/999 | Loss 0.0077 | Win count 439
# Epoch 656/999 | Loss 0.0072 | Win count 440
# Epoch 657/999 | Loss 0.0065 | Win count 441
# Epoch 658/999 | Loss 0.0071 | Win count 441
# Epoch 659/999 | Loss 0.0106 | Win count 442
# Epoch 660/999 | Loss 0.0069 | Win count 442
# Epoch 661/999 | Loss 0.0091 | Win count 443
# Epoch 662/999 | Loss 0.0135 | Win count 444
# Epoch 663/999 | Loss 0.0049 | Win count 445
# Epoch 664/999 | Loss 0.0093 | Win count 446
# Epoch 665/999 | Loss 0.0088 | Win count 447
# Epoch 666/999 | Loss 0.0085 | Win count 448
# Epoch 667/999 | Loss 0.0125 | Win count 449
# Epoch 668/999 | Loss 0.0103 | Win count 450
# Epoch 669/999 | Loss 0.0106 | Win count 451
# Epoch 670/999 | Loss 0.0161 | Win count 452
# Epoch 671/999 | Loss 0.0101 | Win count 453
# Epoch 672/999 | Loss 0.0125 | Win count 454
# Epoch 673/999 | Loss 0.0109 | Win count 455
# Epoch 674/999 | Loss 0.0105 | Win count 456
# Epoch 675/999 | Loss 0.0072 | Win count 457
# Epoch 676/999 | Loss 0.0076 | Win count 458
# Epoch 677/999 | Loss 0.0092 | Win count 459
# Epoch 678/999 | Loss 0.0113 | Win count 460
# Epoch 679/999 | Loss 0.0077 | Win count 461
# Epoch 680/999 | Loss 0.0104 | Win count 462
# Epoch 681/999 | Loss 0.0131 | Win count 462
# Epoch 682/999 | Loss 0.0206 | Win count 463
# Epoch 683/999 | Loss 0.0118 | Win count 464
# Epoch 684/999 | Loss 0.0197 | Win count 465
# Epoch 685/999 | Loss 0.0194 | Win count 466
# Epoch 686/999 | Loss 0.0261 | Win count 467
# Epoch 687/999 | Loss 0.0287 | Win count 467
# Epoch 688/999 | Loss 0.0157 | Win count 468
# Epoch 689/999 | Loss 0.0151 | Win count 469
# Epoch 690/999 | Loss 0.0113 | Win count 470
# Epoch 691/999 | Loss 0.0191 | Win count 471
# Epoch 692/999 | Loss 0.0204 | Win count 472
# Epoch 693/999 | Loss 0.0099 | Win count 473
# Epoch 694/999 | Loss 0.0139 | Win count 474
# Epoch 695/999 | Loss 0.0130 | Win count 475
# Epoch 696/999 | Loss 0.0131 | Win count 476
# Epoch 697/999 | Loss 0.0135 | Win count 477
# Epoch 698/999 | Loss 0.0220 | Win count 478
# Epoch 699/999 | Loss 0.0182 | Win count 479
# Epoch 700/999 | Loss 0.0206 | Win count 480
# Epoch 701/999 | Loss 0.0310 | Win count 481
# Epoch 702/999 | Loss 0.0262 | Win count 482
# Epoch 703/999 | Loss 0.0282 | Win count 483
# Epoch 704/999 | Loss 0.0407 | Win count 484
# Epoch 705/999 | Loss 0.0356 | Win count 485
# Epoch 706/999 | Loss 0.0239 | Win count 486
# Epoch 707/999 | Loss 0.0232 | Win count 487
# Epoch 708/999 | Loss 0.0158 | Win count 488
# Epoch 709/999 | Loss 0.0274 | Win count 489
# Epoch 710/999 | Loss 0.0187 | Win count 490
# Epoch 711/999 | Loss 0.0134 | Win count 491
# Epoch 712/999 | Loss 0.0213 | Win count 492
# Epoch 713/999 | Loss 0.0183 | Win count 493
# Epoch 714/999 | Loss 0.0135 | Win count 494
# Epoch 715/999 | Loss 0.0135 | Win count 495
# Epoch 716/999 | Loss 0.0191 | Win count 496
# Epoch 717/999 | Loss 0.0233 | Win count 497
# Epoch 718/999 | Loss 0.0138 | Win count 498
# Epoch 719/999 | Loss 0.0175 | Win count 499
# Epoch 720/999 | Loss 0.0227 | Win count 500
# Epoch 721/999 | Loss 0.0178 | Win count 501
# Epoch 722/999 | Loss 0.0190 | Win count 502
# Epoch 723/999 | Loss 0.0160 | Win count 503
# Epoch 724/999 | Loss 0.0153 | Win count 503
# Epoch 725/999 | Loss 0.0202 | Win count 504
# Epoch 726/999 | Loss 0.0147 | Win count 505
# Epoch 727/999 | Loss 0.0111 | Win count 506
# Epoch 728/999 | Loss 0.0196 | Win count 507
# Epoch 729/999 | Loss 0.0182 | Win count 508
# Epoch 730/999 | Loss 0.0182 | Win count 509
# Epoch 731/999 | Loss 0.0158 | Win count 509
# Epoch 732/999 | Loss 0.0375 | Win count 510
# Epoch 733/999 | Loss 0.0171 | Win count 511
# Epoch 734/999 | Loss 0.0325 | Win count 512
# Epoch 735/999 | Loss 0.0189 | Win count 513
# Epoch 736/999 | Loss 0.0183 | Win count 514
# Epoch 737/999 | Loss 0.0213 | Win count 515
# Epoch 738/999 | Loss 0.0199 | Win count 516
# Epoch 739/999 | Loss 0.0206 | Win count 517
# Epoch 740/999 | Loss 0.0148 | Win count 517
# Epoch 741/999 | Loss 0.0128 | Win count 518
# Epoch 742/999 | Loss 0.0115 | Win count 519
# Epoch 743/999 | Loss 0.0162 | Win count 520
# Epoch 744/999 | Loss 0.0087 | Win count 521
# Epoch 745/999 | Loss 0.0139 | Win count 522
# Epoch 746/999 | Loss 0.0139 | Win count 523
# Epoch 747/999 | Loss 0.0356 | Win count 524
# Epoch 748/999 | Loss 0.0260 | Win count 525
# Epoch 749/999 | Loss 0.0176 | Win count 526
# Epoch 750/999 | Loss 0.0266 | Win count 527
# Epoch 751/999 | Loss 0.0205 | Win count 528
# Epoch 752/999 | Loss 0.0332 | Win count 529
# Epoch 753/999 | Loss 0.0227 | Win count 530
# Epoch 754/999 | Loss 0.0127 | Win count 531
# Epoch 755/999 | Loss 0.0227 | Win count 532
# Epoch 756/999 | Loss 0.0194 | Win count 533
# Epoch 757/999 | Loss 0.0138 | Win count 534
# Epoch 758/999 | Loss 0.0127 | Win count 535
# Epoch 759/999 | Loss 0.0325 | Win count 536
# Epoch 760/999 | Loss 0.0176 | Win count 537
# Epoch 761/999 | Loss 0.0200 | Win count 538
# Epoch 762/999 | Loss 0.0145 | Win count 539
# Epoch 763/999 | Loss 0.0165 | Win count 540
# Epoch 764/999 | Loss 0.0104 | Win count 541
# Epoch 765/999 | Loss 0.0118 | Win count 542
# Epoch 766/999 | Loss 0.0121 | Win count 543
# Epoch 767/999 | Loss 0.0088 | Win count 544
# Epoch 768/999 | Loss 0.0225 | Win count 545
# Epoch 769/999 | Loss 0.0080 | Win count 546
# Epoch 770/999 | Loss 0.0241 | Win count 547
# Epoch 771/999 | Loss 0.0101 | Win count 548
# Epoch 772/999 | Loss 0.0163 | Win count 549
# Epoch 773/999 | Loss 0.0170 | Win count 550
# Epoch 774/999 | Loss 0.0102 | Win count 551
# Epoch 775/999 | Loss 0.0159 | Win count 552
# Epoch 776/999 | Loss 0.0200 | Win count 553
# Epoch 777/999 | Loss 0.0119 | Win count 554
# Epoch 778/999 | Loss 0.0091 | Win count 555
# Epoch 779/999 | Loss 0.0095 | Win count 556
# Epoch 780/999 | Loss 0.0098 | Win count 557
# Epoch 781/999 | Loss 0.0152 | Win count 558
# Epoch 782/999 | Loss 0.0102 | Win count 559
# Epoch 783/999 | Loss 0.0131 | Win count 560
# Epoch 784/999 | Loss 0.0127 | Win count 561
# Epoch 785/999 | Loss 0.0111 | Win count 562
# Epoch 786/999 | Loss 0.0189 | Win count 563
# Epoch 787/999 | Loss 0.0098 | Win count 564
# Epoch 788/999 | Loss 0.0090 | Win count 565
# Epoch 789/999 | Loss 0.0113 | Win count 566
# Epoch 790/999 | Loss 0.0085 | Win count 567
# Epoch 791/999 | Loss 0.0068 | Win count 568
# Epoch 792/999 | Loss 0.0064 | Win count 569
# Epoch 793/999 | Loss 0.0065 | Win count 570
# Epoch 794/999 | Loss 0.0064 | Win count 571
# Epoch 795/999 | Loss 0.0064 | Win count 572
# Epoch 796/999 | Loss 0.0078 | Win count 573
# Epoch 797/999 | Loss 0.0070 | Win count 574
# Epoch 798/999 | Loss 0.0063 | Win count 575
# Epoch 799/999 | Loss 0.0071 | Win count 576
# Epoch 800/999 | Loss 0.0055 | Win count 577
# Epoch 801/999 | Loss 0.0048 | Win count 578
# Epoch 802/999 | Loss 0.0044 | Win count 579
# Epoch 803/999 | Loss 0.0077 | Win count 580
# Epoch 804/999 | Loss 0.0075 | Win count 580
# Epoch 805/999 | Loss 0.0105 | Win count 581
# Epoch 806/999 | Loss 0.0098 | Win count 582
# Epoch 807/999 | Loss 0.0107 | Win count 583
# Epoch 808/999 | Loss 0.0098 | Win count 584
# Epoch 809/999 | Loss 0.0165 | Win count 585
# Epoch 810/999 | Loss 0.0117 | Win count 586
# Epoch 811/999 | Loss 0.0110 | Win count 587
# Epoch 812/999 | Loss 0.0134 | Win count 588
# Epoch 813/999 | Loss 0.0094 | Win count 589
# Epoch 814/999 | Loss 0.0076 | Win count 590
# Epoch 815/999 | Loss 0.0102 | Win count 591
# Epoch 816/999 | Loss 0.0085 | Win count 591
# Epoch 817/999 | Loss 0.0118 | Win count 592
# Epoch 818/999 | Loss 0.0091 | Win count 593
# Epoch 819/999 | Loss 0.0090 | Win count 594
# Epoch 820/999 | Loss 0.0097 | Win count 595
# Epoch 821/999 | Loss 0.0105 | Win count 596
# Epoch 822/999 | Loss 0.0078 | Win count 597
# Epoch 823/999 | Loss 0.0280 | Win count 598
# Epoch 824/999 | Loss 0.0195 | Win count 599
# Epoch 825/999 | Loss 0.0222 | Win count 599
# Epoch 826/999 | Loss 0.0326 | Win count 600
# Epoch 827/999 | Loss 0.0176 | Win count 601
# Epoch 828/999 | Loss 0.0147 | Win count 602
# Epoch 829/999 | Loss 0.0180 | Win count 603
# Epoch 830/999 | Loss 0.0089 | Win count 604
# Epoch 831/999 | Loss 0.0172 | Win count 605
# Epoch 832/999 | Loss 0.0239 | Win count 606
# Epoch 833/999 | Loss 0.0159 | Win count 607
# Epoch 834/999 | Loss 0.0185 | Win count 608
# Epoch 835/999 | Loss 0.0142 | Win count 609
# Epoch 836/999 | Loss 0.0150 | Win count 610
# Epoch 837/999 | Loss 0.0110 | Win count 611
# Epoch 838/999 | Loss 0.0168 | Win count 612
# Epoch 839/999 | Loss 0.0196 | Win count 613
# Epoch 840/999 | Loss 0.0167 | Win count 614
# Epoch 841/999 | Loss 0.0184 | Win count 615
# Epoch 842/999 | Loss 0.0118 | Win count 616
# Epoch 843/999 | Loss 0.0118 | Win count 617
# Epoch 844/999 | Loss 0.0133 | Win count 618
# Epoch 845/999 | Loss 0.0149 | Win count 619
# Epoch 846/999 | Loss 0.0146 | Win count 619
# Epoch 847/999 | Loss 0.0189 | Win count 620
# Epoch 848/999 | Loss 0.0342 | Win count 621
# Epoch 849/999 | Loss 0.0280 | Win count 622
# Epoch 850/999 | Loss 0.0208 | Win count 623
# Epoch 851/999 | Loss 0.0227 | Win count 624
# Epoch 852/999 | Loss 0.0116 | Win count 625
# Epoch 853/999 | Loss 0.0308 | Win count 626
# Epoch 854/999 | Loss 0.0133 | Win count 627
# Epoch 855/999 | Loss 0.0154 | Win count 628
# Epoch 856/999 | Loss 0.0193 | Win count 629
# Epoch 857/999 | Loss 0.0130 | Win count 630
# Epoch 858/999 | Loss 0.0320 | Win count 631
# Epoch 859/999 | Loss 0.0183 | Win count 632
# Epoch 860/999 | Loss 0.0163 | Win count 633
# Epoch 861/999 | Loss 0.0168 | Win count 634
# Epoch 862/999 | Loss 0.0484 | Win count 635
# Epoch 863/999 | Loss 0.0179 | Win count 636
# Epoch 864/999 | Loss 0.0217 | Win count 637
# Epoch 865/999 | Loss 0.0188 | Win count 638
# Epoch 866/999 | Loss 0.0184 | Win count 638
# Epoch 867/999 | Loss 0.0339 | Win count 639
# Epoch 868/999 | Loss 0.0218 | Win count 640
# Epoch 869/999 | Loss 0.0294 | Win count 641
# Epoch 870/999 | Loss 0.0201 | Win count 642
# Epoch 871/999 | Loss 0.0235 | Win count 643
# Epoch 872/999 | Loss 0.0248 | Win count 644
# Epoch 873/999 | Loss 0.0194 | Win count 644
# Epoch 874/999 | Loss 0.0296 | Win count 645
# Epoch 875/999 | Loss 0.0239 | Win count 646
# Epoch 876/999 | Loss 0.0234 | Win count 647
# Epoch 877/999 | Loss 0.0237 | Win count 648
# Epoch 878/999 | Loss 0.0274 | Win count 649
# Epoch 879/999 | Loss 0.0225 | Win count 650
# Epoch 880/999 | Loss 0.0236 | Win count 651
# Epoch 881/999 | Loss 0.0241 | Win count 652
# Epoch 882/999 | Loss 0.0235 | Win count 653
# Epoch 883/999 | Loss 0.0190 | Win count 653
# Epoch 884/999 | Loss 0.0235 | Win count 654
# Epoch 885/999 | Loss 0.0203 | Win count 655
# Epoch 886/999 | Loss 0.0154 | Win count 656
# Epoch 887/999 | Loss 0.0157 | Win count 657
# Epoch 888/999 | Loss 0.0162 | Win count 658
# Epoch 889/999 | Loss 0.0192 | Win count 659
# Epoch 890/999 | Loss 0.0162 | Win count 660
# Epoch 891/999 | Loss 0.0142 | Win count 661
# Epoch 892/999 | Loss 0.0231 | Win count 661
# Epoch 893/999 | Loss 0.0249 | Win count 662
# Epoch 894/999 | Loss 0.0108 | Win count 663
# Epoch 895/999 | Loss 0.0222 | Win count 664
# Epoch 896/999 | Loss 0.0162 | Win count 665
# Epoch 897/999 | Loss 0.0162 | Win count 666
# Epoch 898/999 | Loss 0.0161 | Win count 667
# Epoch 899/999 | Loss 0.0224 | Win count 668
# Epoch 900/999 | Loss 0.0131 | Win count 669
# Epoch 901/999 | Loss 0.0192 | Win count 670
# Epoch 902/999 | Loss 0.0177 | Win count 671
# Epoch 903/999 | Loss 0.0158 | Win count 672
# Epoch 904/999 | Loss 0.0184 | Win count 672
# Epoch 905/999 | Loss 0.0170 | Win count 673
# Epoch 906/999 | Loss 0.0207 | Win count 674
# Epoch 907/999 | Loss 0.0190 | Win count 675
# Epoch 908/999 | Loss 0.0168 | Win count 675
# Epoch 909/999 | Loss 0.0188 | Win count 676
# Epoch 910/999 | Loss 0.0139 | Win count 677
# Epoch 911/999 | Loss 0.0269 | Win count 678
# Epoch 912/999 | Loss 0.0196 | Win count 679
# Epoch 913/999 | Loss 0.0222 | Win count 680
# Epoch 914/999 | Loss 0.0149 | Win count 681
# Epoch 915/999 | Loss 0.0178 | Win count 682
# Epoch 916/999 | Loss 0.0159 | Win count 683
# Epoch 917/999 | Loss 0.0149 | Win count 684
# Epoch 918/999 | Loss 0.0133 | Win count 685
# Epoch 919/999 | Loss 0.0112 | Win count 686
# Epoch 920/999 | Loss 0.0105 | Win count 687
# Epoch 921/999 | Loss 0.0073 | Win count 688
# Epoch 922/999 | Loss 0.0095 | Win count 689
# Epoch 923/999 | Loss 0.0100 | Win count 690
# Epoch 924/999 | Loss 0.0100 | Win count 691
# Epoch 925/999 | Loss 0.0104 | Win count 692
# Epoch 926/999 | Loss 0.0069 | Win count 693
# Epoch 927/999 | Loss 0.0099 | Win count 693
# Epoch 928/999 | Loss 0.0074 | Win count 694
# Epoch 929/999 | Loss 0.0206 | Win count 695
# Epoch 930/999 | Loss 0.0107 | Win count 696
# Epoch 931/999 | Loss 0.0064 | Win count 697
# Epoch 932/999 | Loss 0.0123 | Win count 698
# Epoch 933/999 | Loss 0.0078 | Win count 699
# Epoch 934/999 | Loss 0.0067 | Win count 700
# Epoch 935/999 | Loss 0.0071 | Win count 701
# Epoch 936/999 | Loss 0.0052 | Win count 702
# Epoch 937/999 | Loss 0.0042 | Win count 703
# Epoch 938/999 | Loss 0.0078 | Win count 704
# Epoch 939/999 | Loss 0.0052 | Win count 705
# Epoch 940/999 | Loss 0.0070 | Win count 706
# Epoch 941/999 | Loss 0.0047 | Win count 707
# Epoch 942/999 | Loss 0.0066 | Win count 708
# Epoch 943/999 | Loss 0.0057 | Win count 709
# Epoch 944/999 | Loss 0.0064 | Win count 710
# Epoch 945/999 | Loss 0.0051 | Win count 711
# Epoch 946/999 | Loss 0.0049 | Win count 712
# Epoch 947/999 | Loss 0.0038 | Win count 713
# Epoch 948/999 | Loss 0.0090 | Win count 714
# Epoch 949/999 | Loss 0.0043 | Win count 715
# Epoch 950/999 | Loss 0.0088 | Win count 716
# Epoch 951/999 | Loss 0.0061 | Win count 717
# Epoch 952/999 | Loss 0.0045 | Win count 718
# Epoch 953/999 | Loss 0.0065 | Win count 718
# Epoch 954/999 | Loss 0.0161 | Win count 718
# Epoch 955/999 | Loss 0.0252 | Win count 719
# Epoch 956/999 | Loss 0.0108 | Win count 720
# Epoch 957/999 | Loss 0.0049 | Win count 721
# Epoch 958/999 | Loss 0.0096 | Win count 722
# Epoch 959/999 | Loss 0.0092 | Win count 723
# Epoch 960/999 | Loss 0.0037 | Win count 724
# Epoch 961/999 | Loss 0.0109 | Win count 725
# Epoch 962/999 | Loss 0.0036 | Win count 726
# Epoch 963/999 | Loss 0.0100 | Win count 727
# Epoch 964/999 | Loss 0.0041 | Win count 728
# Epoch 965/999 | Loss 0.0064 | Win count 729
# Epoch 966/999 | Loss 0.0060 | Win count 730
# Epoch 967/999 | Loss 0.0059 | Win count 730
# Epoch 968/999 | Loss 0.0101 | Win count 731
# Epoch 969/999 | Loss 0.0168 | Win count 732
# Epoch 970/999 | Loss 0.0110 | Win count 733
# Epoch 971/999 | Loss 0.0213 | Win count 734
# Epoch 972/999 | Loss 0.0084 | Win count 735
# Epoch 973/999 | Loss 0.0056 | Win count 736
# Epoch 974/999 | Loss 0.0030 | Win count 737
# Epoch 975/999 | Loss 0.0146 | Win count 738
# Epoch 976/999 | Loss 0.0245 | Win count 739
# Epoch 977/999 | Loss 0.0100 | Win count 740
# Epoch 978/999 | Loss 0.0105 | Win count 741
# Epoch 979/999 | Loss 0.0044 | Win count 742
# Epoch 980/999 | Loss 0.0081 | Win count 743
# Epoch 981/999 | Loss 0.0176 | Win count 744
# Epoch 982/999 | Loss 0.0079 | Win count 745
# Epoch 983/999 | Loss 0.0039 | Win count 746
# Epoch 984/999 | Loss 0.0081 | Win count 747
# Epoch 985/999 | Loss 0.0111 | Win count 747
# Epoch 986/999 | Loss 0.0143 | Win count 748
# Epoch 987/999 | Loss 0.0080 | Win count 749
# Epoch 988/999 | Loss 0.0122 | Win count 750
# Epoch 989/999 | Loss 0.0080 | Win count 751
# Epoch 990/999 | Loss 0.0104 | Win count 751
# Epoch 991/999 | Loss 0.0233 | Win count 752
# Epoch 992/999 | Loss 0.0401 | Win count 752
# Epoch 993/999 | Loss 0.0229 | Win count 753
# Epoch 994/999 | Loss 0.0110 | Win count 753
# Epoch 995/999 | Loss 0.0145 | Win count 754
# Epoch 996/999 | Loss 0.0244 | Win count 755
# Epoch 997/999 | Loss 0.0154 | Win count 756
# Epoch 998/999 | Loss 0.0346 | Win count 757
# Epoch 999/999 | Loss 0.0366 | Win count 758
# Training completed!

# %% [markdown]
# ### Test...

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from keras.models import model_from_json
from qlearn import Catch

if __name__ == "__main__":
    # Make sure this grid size matches the value used fro training
    grid_size = 10

    with open("model.json", "r") as jfile:
        model = model_from_json(json.load(jfile))
    model.load_weights("model.h5")
    model.compile("sgd", "mse")

    # Define environment, game
    env = Catch(grid_size)
    c = 0
    for e in range(10):
        loss = 0.
        env.reset()
        game_over = False
        # get initial input
        input_t = env.observe()

        plt.imshow(input_t.reshape((grid_size,)*2),
                   interpolation='none', cmap='gray')
        plt.savefig("%03d.png" % c)
        c += 1
        while not game_over:
            input_tm1 = input_t

            # get next action
            q = model.predict(input_tm1)
            action = np.argmax(q[0])

            # apply action, get rewards and new state
            input_t, reward, game_over = env.act(action)

            plt.imshow(input_t.reshape((grid_size,)*2),
                       interpolation='none', cmap='gray')
            plt.savefig("%03d.png" % c)
            c += 1

print("Prediction and images generation completed!")
# Out:
# Prediction and images generation completed!

# %% [markdown]
# ### Create an animated Gif on Mac OS X with imagemagick (similar on Linux)
#
#     > brew install imagemagick --build-from-source
#     > brew upgrade imagemagick
#     > for f in *.png; do mv "$f" "${f#0}"; done
#     # Note: Take the last 25 images since the agent has learned a lot and plays better.
#     > convert -resize 50% -delay 10 -loop 0 {75..99}.png CatchVideogame_RL_Qlearning_Me.gif
#
# The resulting animated gif image:
#
# <img src="CatchVideogame_RL_Qlearning_Me.gif" width=200>
